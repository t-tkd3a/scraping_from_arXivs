# %%
# https://imagisi.com/python-arxiv-line/
import csv
import re
import os
import arxiv
import datetime
import calendar
from googletrans import Translator
from time import sleep

translator = Translator()

# %%
def get_datetime_month_top(dt):
    return datetime.datetime(dt.year, dt.month, 1)

def get_datetime_month_tail(dt):
    day = calendar.monthrange(dt.year, dt.month)[1]
    return datetime.datetime(dt.year, dt.month, day, 23, 59, 59)

def get_datetime_next_month(dt):
    month_day = calendar.monthrange(dt.year, dt.month)[1]
    return datetime.datetime(dt.year, dt.month, month_day) + datetime.timedelta(days=1)

def get_str_datetime__only_numerical_value(dt):
    return(dt.strftime('%Y%m%d%H%M%S'))

def get_str_datetime__for_csv(dt):
    return(dt.strftime('%Y-%m-%d %H:%M:%S'))

# %%
title1 = 'Sparsity in Deep Learning: Pruning and growth for efficient inference and training in neural networks.'
t = translator.translate(title1, src="en" , dest="ja")
print(str(t.text))
# Out:
# 深い学習におけるスパース性ニューラルネットワークにおける効率的な推論と訓練のための剪定と成長

# %%
def get_by_submitted_date(start_date, end_date, category = "cs.AI", base_path = "/hdd/takada/arXivs/"):
    #start_date = year + "0101"
    #end_date = year + "12312359"
    output_csv_fname = base_path + start_date + "_arXiv_" + category + ".csv"
    query = "cat:'" + category + " AND submittedDate:[" + start_date + " TO " + end_date + "]'"
    print("query:"+ query)
    
    # result_list = arxiv.query(query = query, sort_by='submittedDate', sort_order='ascending')
    try:
        search = arxiv.Search(
            query = query, 
            max_results = float('inf'),
            sort_by = arxiv.SortCriterion.SubmittedDate
        )
    except ArithmeticError as e:
        print(e)
        print(type(e))
    
    # num = len(result_list)
    # print(start_date + " arxiv read done. (" + str(num) + ")" )
    # if (num <= 0):
    #    return
    
    header = ['published', 'last_update', 'category' , 'url', 'author', 'title_en', 'abst_en', 'title_jp', 'abst_jp', 'comment', 'journal_reference']
    journal_reference_dummy = ""
    with open(output_csv_fname, 'w') as f:
        writer = csv.writer(f)
        writer.writerow(header)
        c = 0
        for r in search.get():
            title = r.title
            abst = r.summary
            #print("title:", title)
        
            abst = abst.replace("\"","'")
            abst = abst.replace("\n","")

            title_jp =  str(translator.translate(title, src='en' ,dest='ja').text)
            abst_jp =  str(translator.translate(abst, src='en' ,dest='ja').text)
            
            writer.writerow([
                get_str_datetime__for_csv(r.published), 
                get_str_datetime__for_csv(r.updated), 
                category, 
                r.pdf_url, 
                r.authors, 
                title, 
                abst, 
                title_jp, 
                abst_jp, 
                r.comment, 
                journal_reference_dummy
            ])
            if (c%100==0):
                print("c:",c,"\t",r.published)
                print(title_jp)
            c += 1
            sleep(2)

# %%
def getter_by_mounth(start_dt, end_dt, category = "cs.LG"):
    base_path = "/hdd/takada/arXivs/arXiv_" + category + "/"
    os.makedirs(base_path, exist_ok=True)
    current_month = get_datetime_month_top(start_dt)
    end_month = get_datetime_next_month(end_dt)

    while current_month < end_month:
        current_month_top_str = get_str_datetime__only_numerical_value( get_datetime_month_top(current_month) )
        current_month_tail_str = get_str_datetime__only_numerical_value( get_datetime_month_tail(current_month) )
        get_by_submitted_date(current_month_top_str, current_month_tail_str, category, base_path=base_path)
        
        current_month = get_datetime_next_month(current_month)

# %%
getter_by_mounth( datetime.datetime(2010, 1, 1), datetime.datetime.now(), category="cs.LG")
# Out:
# query:cat:'cs.LG AND submittedDate:[20100101000000 TO 20100131235959]'
# c: 0 	 2010-01-29 08:10:26+00:00
# PSOベースのクラスタリングの性能比較
# query:cat:'cs.LG AND submittedDate:[20100201000000 TO 20100228235959]'
# c: 0 	 2010-02-28 18:23:11+00:00
# ネットワークにおける弱いが階層的に構造化されたパターンを検出する
# query:cat:'cs.LG AND submittedDate:[20100301000000 TO 20100331235959]'
# c: 0 	 2010-03-31 01:20:07+00:00
# コンテキストバンディットベースのニュースの推奨アルゴリズムの偏りのないオフライン評価
# query:cat:'cs.LG AND submittedDate:[20100401000000 TO 20100430235959]'
# c: 0 	 2010-04-30 21:52:17+00:00
# 複数の見通しからの学習
# query:cat:'cs.LG AND submittedDate:[20100501000000 TO 20100531235959]'
# c: 0 	 2010-05-31 06:58:11+00:00
# シーケンス予測問題の実現可能なケースと非形成可能な場合の関係について
# query:cat:'cs.LG AND submittedDate:[20100601000000 TO 20100630235959]'
# c: 0 	 2010-06-28 14:40:37+00:00
# バイパリットネットワークにおけるリンク予測問題
# query:cat:'cs.LG AND submittedDate:[20100701000000 TO 20100731235959]'
# c: 0 	 2010-07-29 07:36:49+00:00
# 企業経済的苦痛の評価における支援ベクトルマシンとバック伝播ニューラルネットワークの比較
# query:cat:'cs.LG AND submittedDate:[20100801000000 TO 20100831235959]'
# c: 0 	 2010-08-31 18:54:33+00:00
# 根のようなシロイヌナズナ苗木からの野生型と根のようなアラビリナ苗を区別する表現型特性を定量化するための機械学習法の応用
# query:cat:'cs.LG AND submittedDate:[20100901000000 TO 20100930235959]'
# c: 0 	 2010-09-29 18:55:02+00:00
# 丁寧なパーセプトロン
# query:cat:'cs.LG AND submittedDate:[20101001000000 TO 20101031235959]'
# c: 0 	 2010-10-30 18:30:43+00:00
# 交互線形化法によるスパース逆共分散選択
# query:cat:'cs.LG AND submittedDate:[20101101000000 TO 20101130235959]'
# c: 0 	 2010-11-29 13:34:02+00:00
# 非常にインバランスの取れたデータセットを分類する
# query:cat:'cs.LG AND submittedDate:[20101201000000 TO 20101231235959]'
# c: 0 	 2010-12-31 13:33:14+00:00
# カテゴリカルランダムフィールドへのネイバーの条件付き情報と定義
# query:cat:'cs.LG AND submittedDate:[20110101000000 TO 20110131235959]'
# c: 0 	 2011-01-31 22:21:19+00:00
# クラスタリングのための空間的に対応する比較とコンセンサス
# query:cat:'cs.LG AND submittedDate:[20110201000000 TO 20110228235959]'
# c: 0 	 2011-02-28 19:31:41+00:00
# ニーマン - ピアソン分類、凸性および確率的制約
# query:cat:'cs.LG AND submittedDate:[20110301000000 TO 20110331235959]'
# c: 0 	 2011-03-30 16:30:27+00:00
# 経験的エントロピーについて
# query:cat:'cs.LG AND submittedDate:[20110401000000 TO 20110430235959]'
# c: 0 	 2011-04-29 17:45:50+00:00
# 嗜好誘発と逆強化学習
# query:cat:'cs.LG AND submittedDate:[20110501000000 TO 20110531235959]'
# c: 0 	 2011-05-30 17:02:09+00:00
# 動的余白を持つPercePtron
# query:cat:'cs.LG AND submittedDate:[20110601000000 TO 20110630235959]'
# c: 0 	 2011-06-30 15:03:58+00:00
# 複数のカーネル学習のための損失範囲の改善に関するノート
# query:cat:'cs.LG AND submittedDate:[20110701000000 TO 20110731235959]'
# c: 0 	 2011-07-30 05:12:17+00:00
# CBR COMMONSENSE推論と構造マッピング：調停への応用
# query:cat:'cs.LG AND submittedDate:[20110801000000 TO 20110831235959]'
# c: 0 	 2011-08-31 21:40:00+00:00
# 高移動度条件下での複素LS  -  SVMによるOFDMシステムの非線形チャネル推定
# query:cat:'cs.LG AND submittedDate:[20110901000000 TO 20110930235959]'
# c: 0 	 2011-09-28 20:18:30+00:00
# 統計分類器のドメイン適応
# query:cat:'cs.LG AND submittedDate:[20111001000000 TO 20111031235959]'
# c: 0 	 2011-10-31 21:16:40+00:00
# ネットワーク上の分散最適化と学習のための拡散適応戦略
# query:cat:'cs.LG AND submittedDate:[20111101000000 TO 20111130235959]'
# c: 0 	 2011-11-30 20:17:29+00:00
# 自己調整ヒストグラムのための学習フレームワーク
# query:cat:'cs.LG AND submittedDate:[20111201000000 TO 20111231235959]'
# c: 0 	 2011-12-31 17:29:08+00:00
# Tラーニング
# query:cat:'cs.LG AND submittedDate:[20120101000000 TO 20120131235959]'
# c: 0 	 2012-01-31 17:26:17+00:00
# カーネルとのRobocup-Keetawayを学ぶ
# query:cat:'cs.LG AND submittedDate:[20120201000000 TO 20120229235959]'
# c: 0 	 2012-02-29 22:40:56+00:00
# 明示的な状態期間ディストリビューションを持つ隠れマルコフモデルの推論
# query:cat:'cs.LG AND submittedDate:[20120301000000 TO 20120331235959]'
# c: 0 	 2012-03-31 21:15:28+00:00
# オンライン行列予測のための最適アルゴリズム
# query:cat:'cs.LG AND submittedDate:[20120401000000 TO 20120430235959]'
# c: 0 	 2012-04-30 22:48:37+00:00
# $ QD $  - 一般化：コンセンサス+イノベーションによるマルチエージェント補強学習のための共同分散戦略
# query:cat:'cs.LG AND submittedDate:[20120501000000 TO 20120531235959]'
# c: 0 	 2012-05-30 22:24:50+00:00
# スパース信号回復のための$ \ ell_1 $を超えて最小化
# c: 100 	 2012-05-06 06:03:27+00:00
# 試行錯誤の複雑さについて
# query:cat:'cs.LG AND submittedDate:[20120601000000 TO 20120630235959]'
# c: 0 	 2012-06-30 23:07:03+00:00
# マルチラベル分類と部分フィードバックによるランキングについて
# c: 100 	 2012-06-27 19:59:59+00:00
# わずかな正確なスパース線形分類のための類似性学習
# c: 200 	 2012-06-18 15:36:16+00:00
# ランクネットによる比較ベースの学習
# c: 300 	 2012-06-13 15:33:32+00:00
# 任意の分布による線形非環式モデルの因果的発見
# query:cat:'cs.LG AND submittedDate:[20120701000000 TO 20120731235959]'
# c: 0 	 2012-07-31 14:11:31+00:00
# カーネルリッジ回帰を用いたペプチド - タンパク質結合親和性予測子の学習
# c: 100 	 2012-07-04 16:12:02+00:00
# 最大マージンベイジアンネットワーク
# query:cat:'cs.LG AND submittedDate:[20120801000000 TO 20120831235959]'
# c: 0 	 2012-08-31 22:50:00+00:00
# 一般クラスのコスト関数に対する統計的に適応的な学習（SA L-BFGS）
# query:cat:'cs.LG AND submittedDate:[20120901000000 TO 20120930235959]'
# c: 0 	 2012-09-29 04:58:22+00:00
# 楽観的なエージェントは漸近的に最適です
# query:cat:'cs.LG AND submittedDate:[20121001000000 TO 20121031235959]'
# c: 0 	 2012-10-31 23:47:04+00:00
# $ L_0 $正則化凸コーンプログラミングのための反復ハードしきい値処理方法
# c: 100 	 2012-10-16 17:41:19+00:00
# クラウドソーシングコントロール：複数選択を超えて移動する
# query:cat:'cs.LG AND submittedDate:[20121101000000 TO 20121130235959]'
# c: 0 	 2012-11-30 20:50:40+00:00
# 低ランクテンソルの近似ランク検知因子
# c: 100 	 2012-11-02 03:13:08+00:00
# ディープガウスプロセス
# query:cat:'cs.LG AND submittedDate:[20121201000000 TO 20121231235959]'
# c: 0 	 2012-12-31 21:07:21+00:00
# Betheは境界とグローバル最適値を近似しています
# c: 100 	 2012-12-03 13:00:27+00:00
# 動的推奨システム：予測の精度を向上させるためのクラスタベースのバイアスの使用
# query:cat:'cs.LG AND submittedDate:[20130101000000 TO 20130131235959]'
# c: 0 	 2013-01-31 19:39:03+00:00
# 非対称ネットワークにおける階層的クラスタリングの認識構造
# c: 100 	 2013-01-16 15:49:54+00:00
# Gibbsサンプリングを使用した最小メッセージ長クラスタ化
# c: 200 	 2013-01-01 13:20:27+00:00
# CloudSVM：クラウドコンピューティングシステムのSVM分類器をトレーニングする
# query:cat:'cs.LG AND submittedDate:[20130201000000 TO 20130228235959]'
# c: 0 	 2013-02-28 18:56:56+00:00
# 不確実性のためのオンライン学習を伴うGMMプラリの下でのMMSE推定を用いた正則化NMFを用いたソース分離
# c: 100 	 2013-02-03 22:12:52+00:00
# 局所精度推定を用いた加重過半数投票を用いた分類器アンサンブルのためのゲーム - 理論的フレームワーク
# query:cat:'cs.LG AND submittedDate:[20130301000000 TO 20130331235959]'
# c: 0 	 2013-03-31 06:45:47+00:00
# 並列計算はESSです
# query:cat:'cs.LG AND submittedDate:[20130401000000 TO 20130430235959]'
# c: 0 	 2013-04-30 22:57:12+00:00
# スペクトルクラスタリングによるスパマーのソーシャルネットワークを明らかにする
# query:cat:'cs.LG AND submittedDate:[20130501000000 TO 20130531235959]'
# c: 0 	 2013-05-31 16:24:17+00:00
# 正規化されたm推定量のモデル選択の一貫性について
# query:cat:'cs.LG AND submittedDate:[20130601000000 TO 20130630235959]'
# c: 0 	 2013-06-29 16:36:30+00:00
# 離散ベイズシーケンス予測器に対する濃度と信頼
# c: 100 	 2013-06-03 19:13:53+00:00
# いくつかのポリシー検索動的プログラミングアルゴリズムのパフォーマンス限界について
# query:cat:'cs.LG AND submittedDate:[20130701000000 TO 20130731235959]'
# c: 0 	 2013-07-31 19:18:11+00:00
# 一般化線形モデルの高速同時訓練（FastGlz）
# c: 100 	 2013-07-03 16:55:32+00:00
# 英国一般診療電子ヘルスケアデータベースにおける有害薬物イベントの検出の調査
# query:cat:'cs.LG AND submittedDate:[20130801000000 TO 20130831235959]'
# c: 0 	 2013-08-31 13:39:00+00:00
# 強い凹凸なしの機械学習のための不正確な勾配法の非漸近収束解析
# query:cat:'cs.LG AND submittedDate:[20130901000000 TO 20130930235959]'
# c: 0 	 2013-09-30 12:48:35+00:00
# 戦略的データソースからの線形回帰
# c: 100 	 2013-09-05 23:21:02+00:00
# 暗黙の事前調整とサンプリングによる深さニューラルネットワークのヘッシアンフリー最適化の加速
# query:cat:'cs.LG AND submittedDate:[20131001000000 TO 20131031235959]'
# c: 0 	 2013-10-31 13:47:30+00:00
# ディープ自動gressiveネットワーク
# c: 100 	 2013-10-04 07:29:08+00:00
# 標識された非環式グラフ：指向グラフィカルモデルにおける文脈特異的独立性の一般化
# query:cat:'cs.LG AND submittedDate:[20131101000000 TO 20131130235959]'
# c: 0 	 2013-11-30 01:52:36+00:00
# 1クラスの分類：テクニックの研究とレビューの分類
# c: 100 	 2013-11-07 16:20:02+00:00
# グラファンの確率的ブロックモデル近似：理論と一貫した推定
# query:cat:'cs.LG AND submittedDate:[20131201000000 TO 20131231235959]'
# c: 0 	 2013-12-31 18:17:09+00:00
# 非常に疎圧縮されたカウントを持つまばらな回復
# c: 100 	 2013-12-20 00:21:36+00:00
# 深いスパースコーディングによる教師なし機能学習
# query:cat:'cs.LG AND submittedDate:[20140101000000 TO 20140131235959]'
# c: 0 	 2014-01-31 23:33:21+00:00
# 信念ネットワークにおけるニューラル変分推定と学習
# c: 100 	 2014-01-10 12:23:47+00:00
# ラッソと等価な二次ペナルティーモデル
# query:cat:'cs.LG AND submittedDate:[20140201000000 TO 20140228235959]'
# c: 0 	 2014-02-28 18:54:07+00:00
# 辞書学習への入射幾何学的アプローチ
# c: 100 	 2014-02-09 18:18:33+00:00
# ソフトしきい値化に基づく高速分類のための辞書学習
# query:cat:'cs.LG AND submittedDate:[20140301000000 TO 20140331235959]'
# c: 0 	 2014-03-31 19:43:53+00:00
# ランダム投影のための符号化および近隣検索の近似
# c: 100 	 2014-03-02 04:18:00+00:00
# 異常検出のためのネットワークトラフィック分解
# query:cat:'cs.LG AND submittedDate:[20140401000000 TO 20140430235959]'
# c: 0 	 2014-04-30 21:58:10+00:00
# コンセンサス問題のためのバイクラスタリングフレームワーク
# c: 100 	 2014-04-04 03:31:29+00:00
# AIS  -  MACA  -  Z：スプライシング部位のためのマカベースのクローン分類器、真核生物におけるタンパク質コードおよびプロモーター領域同定
# query:cat:'cs.LG AND submittedDate:[20140501000000 TO 20140531235959]'
# c: 0 	 2014-05-31 23:00:36+00:00
# 幾何学的自己整合性を介した改良グラフラプラシアン
# c: 100 	 2014-05-06 20:02:46+00:00
# 摂動によるトレーニング制限ボルツマンマシン
# query:cat:'cs.LG AND submittedDate:[20140601000000 TO 20140630235959]'
# c: 0 	 2014-06-30 22:00:57+00:00
# 最近傍分類のための収束率
# c: 100 	 2014-06-15 02:39:37+00:00
# 電力需要の間隔予測：新しい二変量EMDベースの支持ベクトル回帰モデリングフレームワーク
# query:cat:'cs.LG AND submittedDate:[20140701000000 TO 20140731235959]'
# c: 0 	 2014-07-31 23:54:16+00:00
# 序数マトリックスデータ分析のための累積制限ボルツマンマシン
# c: 100 	 2014-07-06 20:42:05+00:00
# 二乗和法による辞書学習とテンソル分解
# query:cat:'cs.LG AND submittedDate:[20140801000000 TO 20140831235959]'
# c: 0 	 2014-08-31 10:33:45+00:00
# アドホックマイクロフォンアレイキャリブレーション：ユークリッド距離行列完了アルゴリズムと理論的保証
# c: 100 	 2014-08-07 17:40:36+00:00
# ベイジアンネットワークにおける正確なベイジアン構造発見のための並列アルゴリズム
# query:cat:'cs.LG AND submittedDate:[20140901000000 TO 20140930235959]'
# c: 0 	 2014-09-30 15:49:59+00:00
# 分散検出：有限時間分析とネットワークトポロジーの影響
# c: 100 	 2014-09-08 23:47:51+00:00
# 対称的な非負の定義スマーホーマーを使用した疎加法モデル
# query:cat:'cs.LG AND submittedDate:[20141001000000 TO 20141031235959]'
# c: 0 	 2014-10-31 20:46:44+00:00
# マッチングの検証
# c: 100 	 2014-10-15 11:01:52+00:00
# オンラインブートストラップでトンプソンサンプリング
# query:cat:'cs.LG AND submittedDate:[20141101000000 TO 20141130235959]'
# c: 0 	 2014-11-30 15:48:16+00:00
# 多層ネットワークの損失面
# c: 100 	 2014-11-12 16:22:28+00:00
# 関数近似を伴うTD（0）について：濃度境界と指数関数的収束を有する中心の変形
# query:cat:'cs.LG AND submittedDate:[20141201000000 TO 20141231235959]'
# c: 0 	 2014-12-31 19:36:55+00:00
# accams：マトリックスを簡潔にする
# c: 100 	 2014-12-20 04:11:33+00:00
# ブートストラップを使用したノイズの多いラベルに関する深いニューラルネットワークのトレーニング
# c: 200 	 2014-12-08 02:23:40+00:00
# MLITB：ブラウザでの機械学習
# query:cat:'cs.LG AND submittedDate:[20150101000000 TO 20150131235959]'
# c: 0 	 2015-01-31 21:20:53+00:00
# 検閲ブロックモデルにおけるスペクトル検出
# c: 100 	 2015-01-05 08:07:31+00:00
# 画像分類のためのスパースディープスタッキングネットワーク
# query:cat:'cs.LG AND submittedDate:[20150201000000 TO 20150228235959]'
# c: 0 	 2015-02-28 18:32:45+00:00
# スパースランダムグラフを持つHodgarankのためのクラウドソースサンプリング戦略の分析
# c: 100 	 2015-02-13 23:22:16+00:00
# モノラル源分離のためのマスクと深部再発性ニューラルネットワークの共同最適化
# query:cat:'cs.LG AND submittedDate:[20150301000000 TO 20150331235959]'
# c: 0 	 2015-03-31 23:27:03+00:00
# 適応的に選択された比較を介したクラウドソーシング特徴発見
# c: 100 	 2015-03-12 12:59:25+00:00
# マイクロトピックのグリッドの階層的学習
# query:cat:'cs.LG AND submittedDate:[20150401000000 TO 20150430235959]'
# c: 0 	 2015-04-30 19:53:03+00:00
# ポアソン多項分布の構造、カバー、および学習について
# c: 100 	 2015-04-14 20:05:45+00:00
# 時間進化距離データの確率的クラスタ化
# query:cat:'cs.LG AND submittedDate:[20150501000000 TO 20150531235959]'
# c: 0 	 2015-05-31 13:39:41+00:00
# Hadoopに基づく並列スペクトルクラスタリングアルゴリズム
# c: 100 	 2015-05-12 08:49:54+00:00
# 置換ラデムシャーの複雑さ：伝達的学習のための新しい複雑度尺度
# query:cat:'cs.LG AND submittedDate:[20150601000000 TO 20150630235959]'
# c: 0 	 2015-06-30 23:30:28+00:00
# 増分学習のための高速交差検証
# c: 100 	 2015-06-17 10:17:59+00:00
# 統計的音声合成のための深いノイズ除去オートエンコーダ
# c: 200 	 2015-06-08 16:42:10+00:00
# 強調一時的な学習の収束について
# query:cat:'cs.LG AND submittedDate:[20150701000000 TO 20150731235959]'
# c: 0 	 2015-07-31 20:24:20+00:00
# タクシー宛先予測に適用される人工ニューラルネットワーク
# c: 100 	 2015-07-15 13:08:11+00:00
# 最小密度超過
# query:cat:'cs.LG AND submittedDate:[20150801000000 TO 20150831235959]'
# c: 0 	 2015-08-31 21:45:40+00:00
# 識別草母マニホールドからの転移性肝腫瘍セグメンテーション
# c: 100 	 2015-08-13 06:42:25+00:00
# 予測と診断のための確率論的依存ネットワーク
# query:cat:'cs.LG AND submittedDate:[20150901000000 TO 20150930235959]'
# c: 0 	 2015-09-30 20:10:59+00:00
# スパースサポートを持つWasserStein BaryCenterを用いた高速ディスクリート分布クラスタリング
# c: 100 	 2015-09-14 21:58:43+00:00
# 投票カーネルの正則化
# query:cat:'cs.LG AND submittedDate:[20151001000000 TO 20151031235959]'
# c: 0 	 2015-10-31 18:00:39+00:00
# カーネルベースの回帰と滑らかなスプラインを用いた動的時系列の予測
# c: 100 	 2015-10-15 23:40:13+00:00
# テンソル対マトリックス法：ブロックスパース摂動下のロバストテンソル分解
# query:cat:'cs.LG AND submittedDate:[20151101000000 TO 20151130235959]'
# c: 0 	 2015-11-30 22:38:07+00:00
# オンライン行列を介したビタビよりも速い隠れマルコフモデル - ベクトル（MAX、+） - 乗算
# c: 100 	 2015-11-20 20:27:45+00:00
# ニューラルネットワークにおけるデータ依存パス正規化
# c: 200 	 2015-11-19 15:30:39+00:00
# 拡散表現
# c: 300 	 2015-11-14 18:50:00+00:00
# Deepfool：深いニューラルネットワークを欺くための簡単で正確な方法
# c: 400 	 2015-11-05 19:36:33+00:00
# 自閉症におけるステレオタイプモータ移動検出のための畳み込みニューラルネットワーク
# query:cat:'cs.LG AND submittedDate:[20151201000000 TO 20151231235959]'
# c: 0 	 2015-12-31 22:23:34+00:00
# 分類子を書く：非構造化テキストからの視覚分類器の予測
# c: 100 	 2015-12-15 15:05:00+00:00
# ニューロイメージングのためのパターン認識における因果的および抗因果的学習
# c: 200 	 2015-12-02 01:53:57+00:00
# 深部畳み込みニューラルフィールドを用いたタンパク質二次構造予測
# query:cat:'cs.LG AND submittedDate:[20160101000000 TO 20160131235959]'
# c: 0 	 2016-01-31 19:53:49+00:00
# 盗賊はコンピュータアーキテクチャを満たす：スマートに割り当てられたキャッシュの設計
# c: 100 	 2016-01-12 05:33:03+00:00
# 非負の制約を伴うスパース自己符号器を用いたデータの部分的な表現の深い学習
# query:cat:'cs.LG AND submittedDate:[20160201000000 TO 20160229235959]'
# c: 0 	 2016-02-29 19:59:16+00:00
# 簡単な単調政策の反復
# c: 100 	 2016-02-21 06:27:40+00:00
# バットボールの固有値のためのモデルを学習、視覚化、および利用する
# c: 200 	 2016-02-11 03:06:33+00:00
# 注意深くプールネットワーク
# c: 300 	 2016-02-03 06:31:09+00:00
# K-Variates ++：k平均++のより多くのプラス
# query:cat:'cs.LG AND submittedDate:[20160301000000 TO 20160331235959]'
# c: 0 	 2016-03-31 19:50:45+00:00
# 代理を介した階層的な変更検出
# c: 100 	 2016-03-21 19:51:04+00:00
# ハイパーバンド：ハイパーパラメータ最適化への新しいバンディットベースのアプローチ
# c: 200 	 2016-03-10 14:31:33+00:00
# 正確な疾患予測のための革新的な盗作と分類的アプローチ
# query:cat:'cs.LG AND submittedDate:[20160401000000 TO 20160430235959]'
# c: 0 	 2016-04-30 22:16:22+00:00
# 既知の報酬関数を持つ確率的コンテキストバンディット
# c: 100 	 2016-04-18 03:16:56+00:00
# 意味情報による深い審美的な品質評価
# c: 200 	 2016-04-06 16:36:41+00:00
# 1クラスの最近隣人の変種と正確なアンサンブルの作成の関係
# query:cat:'cs.LG AND submittedDate:[20160501000000 TO 20160531235959]'
# c: 0 	 2016-05-31 22:37:43+00:00
# 確率論的推論プログラムの可能性近似誤差の定量化
# c: 100 	 2016-05-25 04:25:45+00:00
# 半監視テキスト分類のための敵対的な訓練方法
# c: 200 	 2016-05-20 09:52:14+00:00
# 監視抑制カーネルネットワークを監視したエンドツーエンドカーネル学習
# c: 300 	 2016-05-06 14:28:54+00:00
# ガウスプロセスグローバル最適化に基づく自動LQRチューニング
# query:cat:'cs.LG AND submittedDate:[20160601000000 TO 20160630235959]'
# c: 0 	 2016-06-30 23:12:20+00:00
# マルチクラス分類：ミラー降下アプローチ
# c: 100 	 2016-06-21 16:48:25+00:00
# 動的グラフウェーブレットを用いた時間 - 頂点伝搬の追跡
# c: 200 	 2016-06-14 11:44:31+00:00
# 自動音声認識における電話尤度の校正
# c: 300 	 2016-06-06 00:02:20+00:00
# 自動リアルタイムフレア予測の運用のための深い学習アプローチ
# query:cat:'cs.LG AND submittedDate:[20160701000000 TO 20160731235959]'
# c: 0 	 2016-07-31 19:02:39+00:00
# 共変量シフト下の正規化パラメータ推定について
# c: 100 	 2016-07-15 04:28:55+00:00
# Deepqa：深い信念ネットワークによる単蛋白モデル品質の推定の改善
# c: 200 	 2016-07-03 16:09:30+00:00
# Node2vec：ネットワークのスケーラブル機能学習
# query:cat:'cs.LG AND submittedDate:[20160801000000 TO 20160831235959]'
# c: 0 	 2016-08-31 19:55:35+00:00
# ソーシャルネットワークにおけるノード分類へのアプリケーションを用いたオンライン教師付き学習に関するチュートリアル
# c: 100 	 2016-08-18 13:55:41+00:00
# 対数超変換のためのパラメータ学習
# c: 200 	 2016-08-05 03:37:46+00:00
# 集約WasperSteinメトリックと状態登録に基づくHMMSの距離
# query:cat:'cs.LG AND submittedDate:[20160901000000 TO 20160930235959]'
# c: 0 	 2016-09-30 23:13:28+00:00
# サブネットワーク解釈によるネットワークデータからの異常値検出
# c: 100 	 2016-09-21 19:08:15+00:00
# 大規模な作家帰属のための文字レベルおよび多チャンネル畳込みニューラルネットワーク
# c: 200 	 2016-09-12 14:38:08+00:00
# 証明可能な保証を用いたマルチラベル学習
# query:cat:'cs.LG AND submittedDate:[20161001000000 TO 20161031235959]'
# c: 0 	 2016-10-31 22:24:49+00:00
# ベイジアン適応データ解析はサブガウシアリーからの保証
# c: 100 	 2016-10-24 18:12:18+00:00
# ランクワンテンソルモデルの非線形適応アルゴリズム
# c: 200 	 2016-10-14 07:44:33+00:00
# 動的リンク予測への準監視グラフ埋め込みアプローチ
# c: 300 	 2016-10-04 17:24:43+00:00
# 堅牢な機械学習への応用を用いた非偏向最適化のためのスマート確率アルゴリズム
# query:cat:'cs.LG AND submittedDate:[20161101000000 TO 20161130235959]'
# c: 0 	 2016-11-30 20:50:33+00:00
# 複数の状況からの関節因果推論
# c: 100 	 2016-11-22 19:24:49+00:00
# 深部学習におけるヘッセ行使の固有値：特異点以上
# c: 200 	 2016-11-16 06:34:41+00:00
# ネットトリム：パフォーマンス保証を用いた深いニューラルネットワークの凸剪定
# c: 300 	 2016-11-08 20:42:26+00:00
# シーケンス学習への配列のための教師なしプレチレーション
# c: 400 	 2016-11-03 21:08:38+00:00
# 学習アルゴリズム間の陰謀、回路下限と擬似乱数
# query:cat:'cs.LG AND submittedDate:[20161201000000 TO 20161231235959]'
# c: 0 	 2016-12-31 23:25:59+00:00
# ノンパラメトリック回帰およびモデル基準適応制御のための遅延適応型コンチンキー推論
# c: 100 	 2016-12-17 23:33:37+00:00
# EGOTRANSFER：ディープニューラルネットワークを使用したEGOCENTRROTおよび呼気ドメインを越えた運動の移動
# c: 200 	 2016-12-10 00:09:45+00:00
# 音声認識のための積極的な学習：勾配の力
# c: 300 	 2016-12-03 12:16:21+00:00
# BILSTMネットワークを用いた時系列データにおける陽性血液培養検出
# query:cat:'cs.LG AND submittedDate:[20170101000000 TO 20170131235959]'
# c: 0 	 2017-01-31 23:26:06+00:00
# 機械学習技術の統合モバイル顧客のための動的顧客セグメンテーション分析を評価するための機械学習技術の統合
# c: 100 	 2017-01-19 23:43:54+00:00
# 希少病医師ターゲティング：因子グラフアプローチ
# c: 200 	 2017-01-05 17:31:16+00:00
# 符号付きグラフのスペクトル分割に関する研究
# query:cat:'cs.LG AND submittedDate:[20170201000000 TO 20170228235959]'
# c: 0 	 2017-02-28 23:16:19+00:00
# マルチターゲットローカライゼーションのためのマルチセンサデータパターン認識機械学習アプローチ
# c: 100 	 2017-02-24 17:09:22+00:00
# Convnetsモデルの非線形変換
# c: 200 	 2017-02-18 18:18:32+00:00
# 普遍的な近似特性を有する深い確率的構成ネットワーク
# c: 300 	 2017-02-08 09:58:49+00:00
# 早産乳児からの単一のEEGチャンネルにおけるバースト検出のための多機能分類器
# query:cat:'cs.LG AND submittedDate:[20170301000000 TO 20170331235959]'
# c: 0 	 2017-03-31 19:25:00+00:00
# WasserStein Ganのトレーニングの改善
# c: 100 	 2017-03-23 06:19:47+00:00
# 教師なし機能学習におけるゼロシナプスの役割
# c: 200 	 2017-03-16 01:37:25+00:00
# 情報の価値を最適化するための効率的なオンライン学習：理論と対話型のトラブルシューティングへの応用
# c: 300 	 2017-03-08 04:58:51+00:00
# 堅牢な敵対的強化学習
# c: 400 	 2017-03-03 10:27:16+00:00
# 意味画像セグメンテーションの敵対的な例
# query:cat:'cs.LG AND submittedDate:[20170401000000 TO 20170430235959]'
# c: 0 	 2017-04-30 21:30:05+00:00
# ターゲットマトリックス完了
# c: 100 	 2017-04-24 06:09:48+00:00
# 統計学習によるクラウドにおける自動異常検出
# c: 200 	 2017-04-13 14:55:23+00:00
# 高速行列乗算を超えるスペクトル近似：アルゴリズムと硬度
# c: 300 	 2017-04-06 09:37:41+00:00
# テキスト依存話者検証のための時間対照的な学習ベースのDNNボトルネック機能
# query:cat:'cs.LG AND submittedDate:[20170501000000 TO 20170531235959]'
# c: 0 	 2017-05-31 23:13:35+00:00
# ベイジアンの公平性
# c: 100 	 2017-05-27 08:10:40+00:00
# AMPNet：動的ニューラルネットワークのための非同期モデル - 並列トレーニング
# c: 200 	 2017-05-23 16:27:19+00:00
# 世代敵対的ネットにおける継続的な学習
# c: 300 	 2017-05-19 19:06:27+00:00
# フィードバック摂動を伴う地域情報は、神経回路における辞書学習に十分です
# c: 400 	 2017-05-11 12:50:23+00:00
# 高速確率分散は確率的組成最適化のためにADMMを減少させた
# c: 500 	 2017-05-02 06:30:56+00:00
# 機械学習を用いた州分類器にベルの不等式を変換する
# query:cat:'cs.LG AND submittedDate:[20170601000000 TO 20170630235959]'
# c: 0 	 2017-06-30 20:59:44+00:00
# バイナリ分類の不公平を罰する
# c: 100 	 2017-06-23 03:34:03+00:00
# げっ歯類ウィスカー - 三叉神経系の目標駆動ニューラルネットワークモデルに向けて
# c: 200 	 2017-06-16 01:13:04+00:00
# データセットの代数定式化に基づくコンパクトな法律の導出
# c: 300 	 2017-06-10 00:52:05+00:00
# TOEPLITZ逆共分散 - 多変量時系列データのクラスタリング
# c: 400 	 2017-06-05 11:44:35+00:00
# 入出力例から複雑なプログラムの合成に向けて
# query:cat:'cs.LG AND submittedDate:[20170701000000 TO 20170731235959]'
# c: 0 	 2017-07-31 23:36:18+00:00
# 強化学習における移転のための後継機能の使用の利点と制限
# c: 100 	 2017-07-24 12:58:46+00:00
# 世代敵対ネットワークのための可能性推定
# c: 200 	 2017-07-17 14:13:40+00:00
# エラーなしの試用：人間の介入による安全な強化学習に向けて
# c: 300 	 2017-07-09 22:32:09+00:00
# 非線形逐次は確率的盗賊における上腕の識別を受け入れて拒絶する
# c: 400 	 2017-07-01 11:52:37+00:00
# ナビゲートの拡散アウトグラフを使って高速近隣隣接検索
# query:cat:'cs.LG AND submittedDate:[20170801000000 TO 20170831235959]'
# c: 0 	 2017-08-31 23:19:02+00:00
# オンライン畳み込み辞書学習のための最初および2次方式
# c: 100 	 2017-08-22 23:32:19+00:00
# 非線形動力学システムのKoopman演算子のための深いニューラルネットワーク表現の学習
# c: 200 	 2017-08-13 17:38:17+00:00
# スパースと密集した機能の組み合わせを活用する
# c: 300 	 2017-08-04 19:30:13+00:00
# 3D-PRNN：リカレントニューラルネットワークを持つ形状プリミティブの生成
# query:cat:'cs.LG AND submittedDate:[20170901000000 TO 20170930235959]'
# c: 0 	 2017-09-30 21:58:34+00:00
# いくつかのサンプルからのベイズ推定：コミュニティの検出と関連問題
# c: 100 	 2017-09-22 18:36:50+00:00
# 逐次データからの不確定および解釈可能な表現の教師なし学習
# c: 200 	 2017-09-16 19:56:05+00:00
# スピーチHMMから導出されたバブルノイズのための非負HMM：スピーチの強化への応用
# c: 300 	 2017-09-11 23:56:37+00:00
# あなたは何を期待していましたか？Classical Piano Musicの表現力豊かなパフォーマンスを予測する
# c: 400 	 2017-09-05 18:01:39+00:00
# 勧告のための注意喚起繰り返しネットワークを相互作用する
# query:cat:'cs.LG AND submittedDate:[20171001000000 TO 20171031235959]'
# c: 0 	 2017-10-31 23:59:23+00:00
# 組み込みシステムにおけるリアルタイム展開のためのマルチタスク深刻学習モデル
# c: 100 	 2017-10-29 02:04:31+00:00
# ニューラルネットワークとスマートフォンセンサーデータを備えた911通話のフロアレベルの予測
# c: 200 	 2017-10-24 17:08:20+00:00
# データ効率の良い政策検索のための物理学エンジンを介した高速モデル識別
# c: 300 	 2017-10-17 16:51:16+00:00
# 一定のステップサイズを有する確率勾配降下のための収束診断
# c: 400 	 2017-10-11 16:55:14+00:00
# ネットワークデータへの応用を伴うISINGモデルの多岐線関数の集中
# c: 500 	 2017-10-02 20:15:43+00:00
# 後部サンプリングのためのRényi差動プライバシーメカニズム
# query:cat:'cs.LG AND submittedDate:[20171101000000 TO 20171130235959]'
# c: 0 	 2017-11-30 23:37:26+00:00
# 量子状態の経験的学習
# c: 100 	 2017-11-27 18:46:00+00:00
# 分割征服強化学習
# c: 200 	 2017-11-21 19:59:24+00:00
# 深海モデルのリーマン幾何学
# c: 300 	 2017-11-17 18:43:04+00:00
# 責任を予測する：執事を学ぶことによる公平性と正確さの向上
# c: 400 	 2017-11-14 06:29:41+00:00
# データエンコーディングによる分散最適化におけるStraggler緩和
# c: 500 	 2017-11-08 21:11:26+00:00
# 順不同データセットでマルコフチェーンを学ぶ
# c: 600 	 2017-11-04 17:43:07+00:00
# 頑強な脳腫瘍セグメンテーションのための複数モデルとアーキテクチャの集合
# query:cat:'cs.LG AND submittedDate:[20171201000000 TO 20171231235959]'
# c: 0 	 2017-12-31 18:06:25+00:00
# Zoopt：デリバティブフリーの最適化のためのツールボックス
# c: 100 	 2017-12-22 15:09:16+00:00
# カーネル摂動を使用してブーストするための多様化支援ベクターマシン：クラス不均衡と小分離への応用
# c: 200 	 2017-12-17 12:15:08+00:00
# 深部学習を用いたサブサンプリングRFデータからの効率的なBモード超音波画像再構成
# c: 300 	 2017-12-10 14:50:28+00:00
# 画像分類のための畳み込みニューラルネットワーク（CNN）とサポートベクトルマシン（SVM）を組み合わせたアーキテクチャ
# c: 400 	 2017-12-04 06:05:21+00:00
# トピックとラベルの伝播：弱い監視されたテキストの分類のための両方の世界のベスト
# query:cat:'cs.LG AND submittedDate:[20180101000000 TO 20180131235959]'
# c: 0 	 2018-01-31 22:14:09+00:00
# ディープネットワークによる非分解性対策の最適化
# c: 100 	 2018-01-23 20:52:44+00:00
# ベイジアンニューラルネットワーク
# c: 200 	 2018-01-15 17:32:04+00:00
# ディスクリート球を用いた教師なし暗黒分解
# c: 300 	 2018-01-07 16:34:41+00:00
# 現実的で豊かな3D環境で一般化可能なエージェントの構築
# query:cat:'cs.LG AND submittedDate:[20180201000000 TO 20180228235959]'
# c: 0 	 2018-02-28 22:28:08+00:00
# 因果的グラフにおけるセパレータと調整セット：完全な基準とアルゴリズムフレームワーク
# c: 100 	 2018-02-26 09:14:48+00:00
# 深いニューラルネットワークのための表現者定理
# c: 200 	 2018-02-22 09:48:56+00:00
# 機械学習を視覚的分析に統合する際の最新技術
# c: 300 	 2018-02-19 14:19:40+00:00
# グラデーションブースト決定木の影響力のあるトレーニングサンプルを見つける
# c: 400 	 2018-02-15 18:25:32+00:00
# 臨床的テキストからの医療コードの説明可能な予測
# c: 500 	 2018-02-13 16:40:08+00:00
# 予測と拘束：ディープ構造化予測におけるカーディナリティーのモデリング
# c: 600 	 2018-02-11 16:47:45+00:00
# 公正な主成分分析のための凸形式
# c: 700 	 2018-02-07 18:33:20+00:00
# 無意識のデータ歪みに対するタイプI誤差の意図的制御：テキスト分類へのニーマン - ピアソンアプローチ
# c: 800 	 2018-02-01 02:44:56+00:00
# 深部ニューラルネットワークのための分散ニュートン法
# query:cat:'cs.LG AND submittedDate:[20180301000000 TO 20180331235959]'
# c: 0 	 2018-03-31 22:44:28+00:00
# 教師なし表現学習のためのメタラーニング更新ルール
# c: 100 	 2018-03-27 08:31:28+00:00
# 自己監視された深い強化学習での押し上げと把握の間の相乗効果
# c: 200 	 2018-03-22 17:57:16+00:00
# グループ正規化
# c: 300 	 2018-03-18 05:09:53+00:00
# 正の異常値検出と正の不安定な分類のための特徴選択を伴う堅牢なAUC最大化フレームワーク
# c: 400 	 2018-03-13 08:09:20+00:00
# 解釈可能なシステムログ異常検出のための再発性ニューラルネットワーク注意メカニズム
# c: 500 	 2018-03-08 09:43:04+00:00
# Deep Domain Adaptationによるクロスドメイン推奨事項
# c: 600 	 2018-03-04 00:20:29+00:00
# シーケンスモデリングのための一般的な畳み込みネットワークと再発ネットワークの経験的評価
# query:cat:'cs.LG AND submittedDate:[20180401000000 TO 20180430235959]'
# c: 0 	 2018-04-30 23:27:29+00:00
# 病理組織学走査の高速検索のための深いバーコード
# c: 100 	 2018-04-25 12:09:01+00:00
# 類似の関係を持つ不可能な不確定表現学習
# c: 200 	 2018-04-20 05:07:14+00:00
# 敵対的なトレーニングでより堅牢な機能を学ぶ
# c: 300 	 2018-04-16 02:52:45+00:00
# 効率的な二次最適化のためのブロック平均近似
# c: 400 	 2018-04-11 02:10:55+00:00
# COT：離散データの生成モデリングのための協調的訓練
# c: 500 	 2018-04-05 14:24:42+00:00
# 深部強化学習への人間の混合戦略アプローチ
# query:cat:'cs.LG AND submittedDate:[20180501000000 TO 20180531235959]'
# c: 0 	 2018-05-31 21:47:34+00:00
# 自信に基づく人間の予測による確率的に安全なロボット計画
# c: 100 	 2018-05-29 19:55:10+00:00
# イベントによる変分逆制御：データ駆動型報酬定義のための一般的なフレームワーク
# c: 200 	 2018-05-27 12:57:58+00:00
# 部分観測からの動的ネットワークモデル
# c: 300 	 2018-05-24 15:38:07+00:00
# 継続的な学習の堅調な評価に向けて
# c: 400 	 2018-05-22 20:33:52+00:00
# 深部ニューラルネットワークによるレート最適雑音除去
# c: 500 	 2018-05-21 12:15:34+00:00
# あなたはどこに行きますか？：行動からのダイナミクスについての信念を推測する
# c: 600 	 2018-05-18 22:06:38+00:00
# PG-TS：ロジスティックコンテキスト盗賊のためのトンプソンサンプリングの改善
# c: 700 	 2018-05-15 00:24:43+00:00
# 複数のデータセットの識別分析のための非線形次元低減
# c: 800 	 2018-05-09 11:51:52+00:00
# ガウスプロセスによるベイズ最適化におけるカテゴリカルおよび整数値変数を処理する
# c: 900 	 2018-05-03 18:34:52+00:00
# ノイシン：リカレントニューラルネットワークのための偏りのない正則化
# query:cat:'cs.LG AND submittedDate:[20180601000000 TO 20180630235959]'
# c: 0 	 2018-06-30 23:31:00+00:00
# 静止状態機能MRIにおける双晶率の自動同定
# c: 100 	 2018-06-27 04:34:30+00:00
# QT-OPT：ビジョンベースのロボット操作のためのスケーラブルディープ補強学習
# c: 200 	 2018-06-22 21:58:14+00:00
# XGEMS：ブラックボックスモデルを説明するためのExplaarsの生成
# c: 300 	 2018-06-19 19:56:33+00:00
# 大型MIMOのCSIベースの屋外局在化：学習アプローチを用いた実験
# c: 400 	 2018-06-15 20:47:50+00:00
# 不確実性サンプリングのためのデータ効率と誤差の関係について
# c: 500 	 2018-06-13 08:58:49+00:00
# 一般的な分散フレームワークを用いた異議への最大化に基づくアンサンブル剪定
# c: 600 	 2018-06-10 06:17:53+00:00
# 分布上利点アクター - 批評家
# c: 700 	 2018-06-06 23:34:06+00:00
# 仮説空間のサイズに対するニューラルネットワーク深さと幅の選択の影響
# c: 800 	 2018-06-05 02:41:44+00:00
# グラフコンダクタンスを介した正規化スペクトルクラスタリングの理解
# c: 900 	 2018-06-01 16:18:57+00:00
# 深部学習による確率差動方程式とコルモゴロフ方程式の解法
# query:cat:'cs.LG AND submittedDate:[20180701000000 TO 20180731235959]'
# c: 0 	 2018-07-31 23:46:50+00:00
# 対照収縮測定基準を介した安定化可能な動的システムの学習
# c: 100 	 2018-07-27 08:50:13+00:00
# Deeplink：深い学習に基づく新しいリンク予測フレームワーク
# c: 200 	 2018-07-24 10:08:12+00:00
# 肺結節検出の偽陽性低減のためのマルチスケール緩やかな積分CNN
# c: 300 	 2018-07-19 19:04:17+00:00
# 不足しているデータの存在下で教師なしメトリック学習
# c: 400 	 2018-07-17 02:51:52+00:00
# プライバシー保存分類器は、WiFiネットワーク不完全データからの共有モビリティの動作を認識する
# c: 500 	 2018-07-12 15:03:13+00:00
# SCIKIT-MULTIFLOW：マルチ出力ストリーミングフレームワーク
# c: 600 	 2018-07-10 09:24:06+00:00
# グラデーション -  LIPSCHITZを想定していない凸拘束目標のための二重最適化
# c: 700 	 2018-07-06 08:14:27+00:00
# 一握りの試験におけるロボットコントローラ学習政策検索アルゴリズムに関する調査
# c: 800 	 2018-07-03 11:05:13+00:00
# 深部学習の平均フィールド最適制御定式化
# query:cat:'cs.LG AND submittedDate:[20180801000000 TO 20180831235959]'
# c: 0 	 2018-08-31 23:38:41+00:00
# 複合尤度最大化と深部学習を用いたタンパク質間末端接触の予測
# c: 100 	 2018-08-28 19:44:51+00:00
# 会話機械読書における自然言語規則の解釈
# c: 200 	 2018-08-23 16:55:53+00:00
# プライマリサンプルスペースでサンプルを重要度のあることを学ぶ
# c: 300 	 2018-08-20 05:47:41+00:00
# ARMスイッチの制限によるマルチアーム帯域プロセスの一般的なフレームワーク
# c: 400 	 2018-08-14 14:03:47+00:00
# スケーラブル近傍コンポーネント分析による一般化の改善
# c: 500 	 2018-08-09 06:19:39+00:00
# WasserSteinグラデーションフローとしてのポリシー最適化
# c: 600 	 2018-08-03 13:25:39+00:00
# ロバストなスペクトルフィルタリングと異常検出
# query:cat:'cs.LG AND submittedDate:[20180901000000 TO 20180930235959]'
# c: 0 	 2018-09-30 22:57:58+00:00
# 静止点学習と計画のためのいくつかのショット目標推論
# c: 100 	 2018-09-27 22:39:45+00:00
# ペリポソナルスペースでの学習と演技：移動、手の届く、そして握り
# c: 200 	 2018-09-25 12:59:01+00:00
# 一般化添加剤モデルのための高速自動平滑化
# c: 300 	 2018-09-21 06:29:50+00:00
# 残留学習によるマンモグラフィ乳濃度を分類する
# c: 400 	 2018-09-18 07:43:00+00:00
# 深強化学習におけるパラメータ空間ノイズによる等方性と方向探索の切り替え
# c: 500 	 2018-09-14 18:12:21+00:00
# 非マトリックス触覚センサー：把握安定性を予測するための地域の接続性をどのように利用することができますか？
# c: 600 	 2018-09-12 07:31:06+00:00
# グラフ畳み込みネットワークを使用した単語埋め込みに構文と意味情報を組み込む
# c: 700 	 2018-09-10 00:23:25+00:00
# 時変ゲームで学ぶこと
# c: 800 	 2018-09-06 20:50:40+00:00
# ProdSumnet：製品の合計行列分解を介した深いニューラルネットワークにおけるモデルパラメータを減らす
# c: 900 	 2018-09-04 16:28:36+00:00
# 単語センス曖昧性和のための複数の注意を払う新しいニューラルシーケンスモデル
# query:cat:'cs.LG AND submittedDate:[20181001000000 TO 20181031235959]'
# c: 0 	 2018-10-31 23:59:04+00:00
# モジュール化変分オートエンコーダによるメロディック特徴依存性のモデリング
# c: 100 	 2018-10-30 12:23:35+00:00
# 自然言語に関する解釈性のための組成アテンシャルネットワーク
# c: 200 	 2018-10-28 13:37:14+00:00
# 音声認識問題に適用した超高画質ベースの半監視学習アルゴリズム：新しいアプローチ
# c: 300 	 2018-10-25 15:50:57+00:00
# PACモデルにおける量子チャネル学習のためのサンプル効率的アルゴリズムとおおよその状態差別問題
# c: 400 	 2018-10-23 10:22:17+00:00
# ローガン：色で調整された生成敵対的なニューラルネットワークでロゴを生成する
# c: 500 	 2018-10-20 03:12:59+00:00
# MMLSPARK：大規模なスケールでの機械学習生態系を統一します
# c: 600 	 2018-10-17 18:19:39+00:00
# RIN-CLOSE_CVC2：数値データセットのBIClusteringのためのさらに効率的な列挙アルゴリズム
# c: 700 	 2018-10-15 18:30:11+00:00
# エンドツーエンドの深部ニューラルネットワークによる非線形オーディオ効果のモデリング
# c: 800 	 2018-10-11 17:03:44+00:00
# 意味セグメンテーションのための空間的整合性情報に基づく敵対的な例を特徴付ける
# c: 900 	 2018-10-09 06:55:04+00:00
# エンティティ認識のドメインのための強制リクエルニューラルネットワークを用いたインスタンス転送ベースのアプローチ
# c: 1000 	 2018-10-06 10:44:59+00:00
# いつでも確率的な勾配の降下：すべての労働者から聞く時間
# c: 1100 	 2018-10-03 20:45:15+00:00
# クレジット：地震信号検出のための畳み込みユニットと再発ユニットの深い残留ネットワーク
# c: 1200 	 2018-10-01 18:03:24+00:00
# 等高線畳み込みによる多方向測地線ニューラルネットワーク
# query:cat:'cs.LG AND submittedDate:[20181101000000 TO 20181130235959]'
# c: 0 	 2018-11-30 23:42:53+00:00
# 予測のためのガウスプロセスを持つ深い要因
# c: 100 	 2018-11-29 15:08:55+00:00
# 電子健康記録に関する機械学習：瞑想の非密着性を予測するためのモデルと特徴
# c: 200 	 2018-11-27 19:31:29+00:00
# DLHUB：科学のためのモデルとデータ
# c: 300 	 2018-11-25 21:54:02+00:00
# 確率最適化のための不正確なサラアルゴリズム
# c: 400 	 2018-11-22 03:23:44+00:00
# 人工ニューラルネットワークのスパースショートカットトポロジーについて
# c: 500 	 2018-11-20 03:25:19+00:00
# 確率粒子最適化サンプリングの分散減少
# c: 600 	 2018-11-17 09:41:01+00:00
# 教師なしドメイン適応のための深部識別学習
# c: 700 	 2018-11-14 21:33:24+00:00
# 活動時間系列のための敵対的教師なし表現学習
# c: 800 	 2018-11-12 18:45:08+00:00
# 脳腫瘍患者生存予測のための深い学習と古典的な回帰
# c: 900 	 2018-11-09 15:16:55+00:00
# テンソルネットワーク上の積和物ネットワークの深圧縮
# c: 1000 	 2018-11-07 15:47:48+00:00
# 世代敵対政策ネットワークを介した行動レパートリー
# c: 1100 	 2018-11-05 22:49:03+00:00
# クォータ：強化学習のための分位オプションアーキテクチャ
# c: 1200 	 2018-11-02 23:30:54+00:00
# 多言語単語埋め込みのための教師なしのハイパーアライメント
# c: 1300 	 2018-11-01 05:49:40+00:00
# FNNC：ニューラルネットワークを通じて公平性を達成する
# query:cat:'cs.LG AND submittedDate:[20181201000000 TO 20181231235959]'
# c: 0 	 2018-12-31 22:41:32+00:00
# 最小記述長の原理を通して主成分基本性を決定する
# c: 100 	 2018-12-27 16:34:54+00:00
# マージン分布を活用したディープニューラルネットワークの一般化の改善
# c: 200 	 2018-12-23 02:31:11+00:00
# フレーミングのための深いクラスタリングを伴う合理的に不注意な効用関数の推定 -  YouTubeエンゲージメントダイナミクスにおけるアプリケーション
# c: 300 	 2018-12-19 17:19:50+00:00
# ソーシャルメディア分析を用いた観光ドメインにおける意思決定能力の向上
# c: 400 	 2018-12-17 17:02:58+00:00
# TOP-GAN：小型トレーニングセットによる深い学習を用いたラベルフリー癌細胞分類
# c: 500 	 2018-12-14 18:36:06+00:00
# ノンスムース関数のブーストDCアルゴリズム
# c: 600 	 2018-12-11 22:49:14+00:00
# スマート：学習のためのオープンソースデータラベリングプラットフォーム
# c: 700 	 2018-12-10 00:00:33+00:00
# ガウスプロセス状態空間モデルにおける閉形形推論と予測
# c: 800 	 2018-12-06 20:09:40+00:00
# ネットワークエージェントを用いた分散バッチマルチエージェント補強学習のための有限のサンプル解析
# c: 900 	 2018-12-04 22:41:33+00:00
# Boltzmann発電機 - 深部学習を伴う多くの体系のサンプリング均衡状態
# c: 1000 	 2018-12-03 12:17:22+00:00
# 臨床的解釈性のための注意ベースのニューラルネットワークを用いた流体ボーラス療法に対する血圧応答の予測
# query:cat:'cs.LG AND submittedDate:[20190101000000 TO 20190131235959]'
# c: 0 	 2019-01-31 23:59:34+00:00
# ツリス補強学習：最大エントロピー強化学習のための統一された枠組み
# c: 100 	 2019-01-30 12:43:50+00:00
# 効率的なモデル圧縮のための緊張埋め込み層
# c: 200 	 2019-01-29 01:15:34+00:00
# ロバストデザインのための適応サンプリングによるコンディショニング
# c: 300 	 2019-01-26 20:53:39+00:00
# 実用的なLipschitz盗賊に向けて
# c: 400 	 2019-01-24 18:30:20+00:00
# ほぼ決定論的な動的システムのための政策勾配の推定のサンプルの複雑さ
# c: 500 	 2019-01-23 13:04:59+00:00
# 古典的なアプローチから深い学習支援意思決定支援への肺結節の診断を進化させる：30年間の開発コースと将来の見通し
# c: 600 	 2019-01-20 18:45:50+00:00
# 重み付けされたフィーチャ属性の集計に向けて
# c: 700 	 2019-01-16 05:31:08+00:00
# 分類評価によるEEG信号のGAベースの特徴選択：BCIシステムにおける応用
# c: 800 	 2019-01-11 23:13:47+00:00
# ニューラルネットワークをテストするための入力優先順位付け
# c: 900 	 2019-01-08 16:59:46+00:00
# Gilt：長いテキストから画像を生成する
# c: 1000 	 2019-01-05 00:35:43+00:00
# 動的グラフのためのランダムウォークを用いた効率的な表現学習
# c: 1100 	 2019-01-01 09:17:51+00:00
# 学習と分類のための深い学習ネットワークのFPGAベースのアクセラレータ：レビュー
# query:cat:'cs.LG AND submittedDate:[20190201000000 TO 20190228235959]'
# c: 0 	 2019-02-28 22:42:02+00:00
# ディープラーニング拡散重み付きMRIにイントラボクセルインコヒーレントモーションモデルをフィットする方法
# c: 100 	 2019-02-27 09:12:29+00:00
# ハイパーネットワース機能画像表現
# c: 200 	 2019-02-26 00:59:14+00:00
# マルチスケールガウスプロセスレベル設定推定
# c: 300 	 2019-02-22 21:22:52+00:00
# 完全畳み込み自己停電器による乳がん病理組織学画像分類のための識別パターンマイニング
# c: 400 	 2019-02-21 02:36:16+00:00
# 直接安定性定量化による安定したベイズの最適化
# c: 500 	 2019-02-18 19:10:18+00:00
# 子育て：人間の入力からの安全な強化学習
# c: 600 	 2019-02-15 05:28:26+00:00
# AUTOQ：自動カーネルワイズニューラルネットワーク量子化
# c: 700 	 2019-02-12 18:55:18+00:00
# 無限の混合プロトタイプはほんの少しの発現のためのプロトタイプ
# c: 800 	 2019-02-10 17:39:21+00:00
# マルウェア検出の主成分解析を用いた特徴選択を用いた機械学習：ケーススタディ
# c: 900 	 2019-02-08 01:31:02+00:00
# Adascale：適応スケーリングを用いたリアルタイムビデオオブジェクト検出に向けて
# c: 1000 	 2019-02-06 02:46:07+00:00
# ELFミニRTSのニューラル架空の自己遊び
# c: 1100 	 2019-02-04 12:14:52+00:00
# マトリックスマニホールド上のリーマンアダプティブ確率勾配アルゴリズム
# c: 1200 	 2019-02-01 11:13:40+00:00
# フロー++：変分逆量子化とアーキテクチャ設計の流れに基づく生成モデルの改善
# query:cat:'cs.LG AND submittedDate:[20190301000000 TO 20190331235959]'
# c: 0 	 2019-03-31 23:46:26+00:00
# リスク嫌い堅牢な敵対的強化学習
# c: 100 	 2019-03-28 13:30:24+00:00
# グラフニューラルネットワークのためのディスクリート構造の学習
# c: 200 	 2019-03-26 07:16:38+00:00
# 生体音響分類のためのマルチスケールCNNベースの深いメトリック学習：動的三重項損失を用いた研修データの不足の克服
# c: 300 	 2019-03-22 09:15:23+00:00
# グループレベルFMRI分析のための制約付きICA-EMDモデル
# c: 400 	 2019-03-20 09:40:19+00:00
# 弱い監督によるニューラルチェック価値ランキング：事実検査のための文を見つける
# c: 500 	 2019-03-18 06:51:03+00:00
# コンセプトドリフトの存在下でのプロトタイプベースの分類子：モデリングフレームワーク
# c: 600 	 2019-03-14 07:14:34+00:00
# 画像セットベース認識のための制約付き相互凸コーン法
# c: 700 	 2019-03-11 22:14:40+00:00
# 不規則に間隔を置いたデータのためのウェーブレット回帰および加法モデル
# c: 800 	 2019-03-08 15:28:48+00:00
# 深海地域の変分推論を介した教師なしデータの納付
# c: 900 	 2019-03-06 14:50:02+00:00
# Pytorch Geometricによる高速グラフ表現学習
# c: 1000 	 2019-03-04 14:15:07+00:00
# トラフィック参加者のインタラクションをモデル化するためのグラフニューラルネットワーク
# c: 1100 	 2019-03-01 00:30:09+00:00
# グラフクラスタリングの確率ブロックモデルと拡張機能のレビュー
# query:cat:'cs.LG AND submittedDate:[20190401000000 TO 20190430235959]'
# c: 0 	 2019-04-30 23:40:51+00:00
# RESNETは60Xを剪定することができます：体重剪定後のネットワーク浄化および未使用経路除去（P-RM）の導入
# c: 100 	 2019-04-29 09:52:36+00:00
# ドメイン一般化のための精度制約を用いた敵対的不変特徴学習
# c: 200 	 2019-04-26 07:45:48+00:00
# CTスキャンに注釈を付けるための畳み込みオートエンコーダに基づく対話型ユーザインタフェース
# c: 300 	 2019-04-24 08:29:43+00:00
# 線形ニューラルネットのレイヤーダイナミクス
# c: 400 	 2019-04-21 17:09:35+00:00
# hcfContext：逐次履歴ベースの共同フィルタリングによるスマートフォンのコンテキスト推論
# c: 500 	 2019-04-18 09:19:25+00:00
# 長期記憶ネットワークによる言語モデリング
# c: 600 	 2019-04-16 17:52:54+00:00
# アクティブな敵対的ドメイン適応
# c: 700 	 2019-04-14 13:01:46+00:00
# BERT4REC：トランスフォーマーからの双方向エンコーダ表現を用いた順次推奨
# c: 800 	 2019-04-11 13:09:57+00:00
# 教師なしマッピングによるクロストピック分布意味表現
# c: 900 	 2019-04-09 16:15:39+00:00
# アクティブドメインランダム化
# c: 1000 	 2019-04-08 06:26:35+00:00
# 菊地階層とテンソルPCA
# c: 1100 	 2019-04-05 09:39:57+00:00
# Logitron：長期ロジスティックロス関数に基づくパーセプトロン拡張分類モデル
# c: 1200 	 2019-04-03 14:24:04+00:00
# 要約状態表現を使用して文書を共同で抽出し圧縮する
# c: 1300 	 2019-04-01 18:19:11+00:00
# オンラインオフライン実験による政策検索のためのベイジアン最適化
# query:cat:'cs.LG AND submittedDate:[20190501000000 TO 20190531235959]'
# c: 0 	 2019-05-31 23:53:20+00:00
# 深層空間的グラフモデリングのためのグラフ波長セット
# c: 100 	 2019-05-30 22:13:10+00:00
# 非協調マルチエージェント設定における不均一な学習率を伴う勾配ベース学習の収束解析
# c: 200 	 2019-05-30 00:57:15+00:00
# 昆虫類：人口統計のシフトを評価し、分類を改善するためのクラウドソーシングの観察
# c: 300 	 2019-05-29 09:49:21+00:00
# ラフな風景を模して最適な性能を得る方法：平均勾配降下とそのテンソルPCAへの応用
# c: 400 	 2019-05-28 15:31:51+00:00
# ドロップアウトと原子力の規則化
# c: 500 	 2019-05-27 22:24:21+00:00
# 損失関数最適化によるトレーニング速度、精度、およびデータ利用の向上
# c: 600 	 2019-05-27 07:08:12+00:00
# Levenshtein Transformer
# c: 700 	 2019-05-25 23:48:00+00:00
# MDE：知識グラフにおけるリンク予測のための複数の距離埋め込み
# c: 800 	 2019-05-24 15:37:22+00:00
# 敵対的な例に対する機械学習モデルを固定するためのプライバシーリスク
# c: 900 	 2019-05-23 19:38:32+00:00
# Paratuck2テンソル分解のためのAphenを用いたモバイルバンキングにおけるユーザデバイス認証
# c: 1000 	 2019-05-22 16:14:14+00:00
# 大規模分散システムにおけるリソース利用のオンラインコレクションと予測
# c: 1100 	 2019-05-21 03:11:30+00:00
# 類似性保存によるクラスタリング
# c: 1200 	 2019-05-18 00:44:47+00:00
# 地方トピック品質の自動評価
# c: 1300 	 2019-05-16 10:27:04+00:00
# 不完全なRosetta Stoneの問題：マルチビュー非線形ICAの識別可能な結果
# c: 1400 	 2019-05-15 01:37:02+00:00
# 学習ベースの分岐と最大の一般的なサブグラフ問題のためのバインド
# c: 1500 	 2019-05-13 16:55:43+00:00
# センサ分析のための連合マルチタスク階層的注意モデル
# c: 1600 	 2019-05-10 22:31:22+00:00
# ファジィ一体型ニューラルネットワークを用いた深い学習における説明可能な融合を可能にする
# c: 1700 	 2019-05-09 11:38:57+00:00
# RBFニューラルネットワーク用の新しい適応カーネル
# c: 1800 	 2019-05-07 03:42:04+00:00
# 量子乱数発生器の機械学習暗号解読
# c: 1900 	 2019-05-03 21:43:35+00:00
# 静的起動関数正規化
# c: 2000 	 2019-05-01 16:51:52+00:00
# ADMMベースのAutomLパイプライン構成のフレームワーク
# query:cat:'cs.LG AND submittedDate:[20190601000000 TO 20190630235959]'
# c: 0 	 2019-06-30 23:58:28+00:00
# オーディオスプーフィング検出のための深い残留ニューラルネットワーク
# c: 100 	 2019-06-28 08:17:53+00:00
# チュートリアル：特異値分解とその変種の複雑さ解析
# c: 200 	 2019-06-26 11:52:49+00:00
# テンポ不変オーディオシート音楽検索のためのソフト注意モデルの学習
# c: 300 	 2019-06-24 19:24:09+00:00
# 共同創造的設計システムにおける概念シフトのための計算モデルにおける深い学習
# c: 400 	 2019-06-22 09:10:29+00:00
# ガウスプロセスを用いた集約データのマルチタスク学習
# c: 500 	 2019-06-20 15:57:26+00:00
# ラベル依存関係転送とペアワイズ埋め込みを備えたいくつかのショットシーケンスラベル
# c: 600 	 2019-06-19 09:22:22+00:00
# 州の不確実性推定を用いた政策評価のための適応的時間差学習
# c: 700 	 2019-06-17 22:38:00+00:00
# C-SALT：ブールマトリックス因数分解におけるマイニングクラス固有の変更
# c: 800 	 2019-06-15 20:56:48+00:00
# ヨガ - ビーガニズム：Twitterの健康データの相関マイニング
# c: 900 	 2019-06-13 17:49:20+00:00
# 対照的なマルチビューコーディング
# c: 1000 	 2019-06-12 15:18:36+00:00
# 半監視画像分類のための学習プロトタイプを持つマニホールドグラフ
# c: 1100 	 2019-06-11 11:56:47+00:00
# ガウス潜変数の有限サンプルに基づく近似変分推論
# c: 1200 	 2019-06-10 12:35:01+00:00
# CVPR19追跡と検出チャレンジ：それがどのように混雑してもらえますか？
# c: 1300 	 2019-06-08 19:13:26+00:00
# 畳み込み二分光アトラクタネットワーク
# c: 1400 	 2019-06-07 03:16:08+00:00
# 加重ネットワークの頂点分類
# c: 1500 	 2019-06-06 02:33:09+00:00
# $ \ mathcal {O}（N ^ 2）$ hyper-parameterの最適化交差検定と非線形に制約されていないADMMを使用したガウスプロセス回帰
# c: 1600 	 2019-06-04 21:28:31+00:00
# 文法誤り訂正における変圧器言語モデルの不当な有効性
# c: 1700 	 2019-06-03 23:38:33+00:00
# 政策模倣の敵対的搾取
# c: 1800 	 2019-06-03 02:33:01+00:00
# モジュラーアーキテクチャを使用した部分ラベルによる感情タグ付け
# query:cat:'cs.LG AND submittedDate:[20190701000000 TO 20190731235959]'
# c: 0 	 2019-07-31 23:51:51+00:00
# パーソナライズされた健康対応レシピ推奨事項：アンサンブルトピックモデリングベースのアプローチ
# c: 100 	 2019-07-30 02:21:43+00:00
# 関数クエリの複雑さを伴う非偏心ゼロ次論的確率的ADMM法
# c: 200 	 2019-07-26 19:01:48+00:00
# パーソナライズされた検索ストーリーのための深い強化学習
# c: 300 	 2019-07-24 22:43:55+00:00
# 特徴散乱に基づく敵対的訓練を用いた敵対的攻撃に対する防御
# c: 400 	 2019-07-23 08:45:57+00:00
# スーパーミックス：混合物のスパースの正則化
# c: 500 	 2019-07-22 00:18:34+00:00
# マルコフ毛布とセレバ様データセットでバイアスを覆ってください：属性前回回避のためのポストクロック
# c: 600 	 2019-07-18 19:29:29+00:00
# 作家フォーシング：より面白いストーリーエンドを生み出す
# c: 700 	 2019-07-17 02:38:37+00:00
# サイド情報による動的最適化
# c: 800 	 2019-07-15 09:23:49+00:00
# 光沢：文表現の生成潜在的最適化
# c: 900 	 2019-07-12 08:57:26+00:00
# ラプラシア語 - 正則化グラフ帯状：アルゴリズムと理論解析
# c: 1000 	 2019-07-10 13:32:14+00:00
# 列車の海上問題に対する実現可能性決定に関するデータ駆動方針
# c: 1100 	 2019-07-08 21:11:24+00:00
# 再構成木によるマルチスケールベクトル量子化
# c: 1200 	 2019-07-06 04:53:49+00:00
# 解釈可能かつ堅牢なAV認識のためのアフィンの不在GaN
# c: 1300 	 2019-07-04 02:54:02+00:00
# 神経系配列標識を用いたサイバーセキュリティ物品の非構造化テキストからの妥協点の収集指標
# c: 1400 	 2019-07-02 19:55:33+00:00
# MIDI-Sandwich：シンボリックシングルトラックミュージックジェネレーションのためのマルチモデルマルチタスク階層型の条件付きVAE-GANネットワーク
# c: 1500 	 2019-07-01 14:44:41+00:00
# 深い時間的外観マッチング協会を用いたオンライン複数の歩行者追跡
# query:cat:'cs.LG AND submittedDate:[20190801000000 TO 20190831235959]'
# c: 0 	 2019-08-31 22:50:42+00:00
# 人物再識別のための二次非地域の注意ネットワーク
# c: 100 	 2019-08-29 13:54:08+00:00
# 転送学習に対する誤分類攻撃を破壊することに向けて
# c: 200 	 2019-08-27 17:25:01+00:00
# 順方向UQ分析における完全確率分布を推定するための新規な能動的学習ベースのガウスプロセスメタモデル化戦略
# c: 300 	 2019-08-26 00:34:16+00:00
# デコンボリューション顕微鏡のためのぼけカーネルを使ったサイクルガン：最適輸送ジオメトリ
# c: 400 	 2019-08-23 01:22:04+00:00
# 機械学習におけるバイアスと公平性に関する調査
# c: 500 	 2019-08-21 02:26:44+00:00
# 意味分割のための非対称非局所ニューラルネットワーク
# c: 600 	 2019-08-19 09:21:45+00:00
# ガウス混合モデルのための量子期待 - 最大化
# c: 700 	 2019-08-16 13:01:30+00:00
# Commentsradar：Web上のすべてのコメントに関するユニークなデータにダイビング
# c: 800 	 2019-08-14 15:11:31+00:00
# 制約のない単調ニューラルネットワーク
# c: 900 	 2019-08-12 08:27:49+00:00
# ミックス＆マッチ：精度を向上させるための画像サイズを混在させたトレーニングConvnets
# c: 1000 	 2019-08-08 20:51:17+00:00
# 適応学習率とそれ以上の分散について
# c: 1100 	 2019-08-06 12:56:17+00:00
# 経験的Ai
# c: 1200 	 2019-08-03 17:52:13+00:00
# 時間的インタラクションネットワークにおける動的埋め込み軌道の予測
# c: 1300 	 2019-08-01 08:22:18+00:00
# 政策勾配法の理論について：最適性、近似、分布シフト
# query:cat:'cs.LG AND submittedDate:[20190901000000 TO 20190930235959]'
# c: 0 	 2019-09-30 23:47:55+00:00
# Hotel2vec：自己監督を備えた属性対応ホテル埋め込み
# c: 100 	 2019-09-29 17:06:13+00:00
# 高次元データ可視化のための容量保存マッピング
# c: 200 	 2019-09-27 08:08:09+00:00
# 無線マルチキャストシステムのための深強化学習ベースの電力制御
# c: 300 	 2019-09-26 05:48:16+00:00
# 2つのタイムスケールオフポリシーTD学習：マルコフのサンプルに対する非漸近分析
# c: 400 	 2019-09-25 08:27:25+00:00
# OctNet：過去の経験からの新しい環境における軌道生成
# c: 500 	 2019-09-23 18:54:52+00:00
# 厳密な部分順序ネットワークを用いた超新生検出
# c: 600 	 2019-09-20 13:49:50+00:00
# 補強学習を用いたリダイレクトコントローラ
# c: 700 	 2019-09-18 19:15:35+00:00
# バッチ正規化はどのようにしてバイナリトレーニングを助けますか？
# c: 800 	 2019-09-17 13:01:12+00:00
# トランスフォーマープレトレーニングによるスパンベースの関節エンティティと関係抽出
# c: 900 	 2019-09-16 09:15:53+00:00
# 正確な二元神経アーキテクチャを探す
# c: 1000 	 2019-09-13 20:23:40+00:00
# マルチタスク学習のための適応スケジューリング
# c: 1100 	 2019-09-12 13:46:58+00:00
# UE：トレーニング前モデルのためのオープンソースツールキット
# c: 1200 	 2019-09-10 21:16:04+00:00
# 複数のスパイクコードをサポートする時間圧縮を用いたハードウェアスパイキングニューラルアクセラレータのスループットと効率を高める
# c: 1300 	 2019-09-09 18:10:06+00:00
# サブスペースグラフ学習に基づく分類方法論
# c: 1400 	 2019-09-08 08:41:05+00:00
# オープン複合ドメイン適応
# c: 1500 	 2019-09-06 07:22:01+00:00
# 勾配ベースの摂動を用いた自然な敵対的文の生成
# c: 1600 	 2019-09-04 13:58:11+00:00
# ALIME：局所解釈性のためのオートエンコーダベースのアプローチ
# c: 1700 	 2019-09-03 02:11:11+00:00
# 構造化非蒸気最適化のための座標下降法の効率化
# query:cat:'cs.LG AND submittedDate:[20191001000000 TO 20191031235959]'
# c: 0 	 2019-10-31 23:11:21+00:00
# WeBly監視データを用いた画像の政治の予測
# c: 100 	 2019-10-30 20:32:01+00:00
# 公正なのは何ですか？公平性制約分類子のためのパレート効率を探索する
# c: 200 	 2019-10-29 16:58:25+00:00
# マルチステップ操作のためのカスケード変分推論によるダイナミクス学習
# c: 300 	 2019-10-28 16:52:25+00:00
# 深部学習は異方性Besov空間におけるモデルの滑らかさの固有の次元に適応しています
# c: 400 	 2019-10-27 06:47:16+00:00
# 拡散測定基準を用いた確率勾配降下の幾何学的解釈
# c: 500 	 2019-10-25 06:13:08+00:00
# 強い丸太凹部は、ログ類の並べ替えを意味するものではありません
# c: 600 	 2019-10-23 19:02:43+00:00
# 悪性腫瘍のMRガイド付き集束超音波処理を評価するためのマルチパラメトリックバイオマーカーの学習
# c: 700 	 2019-10-22 16:15:58+00:00
# 深さ適応型トランス
# c: 800 	 2019-10-21 16:39:42+00:00
# S4NN：ニューロンごとに1つのスパイクを用いたニューラルネットワークスパイクの時間的逆流
# c: 900 	 2019-10-20 18:30:23+00:00
# 専門家とデータの両方からの学習
# c: 1000 	 2019-10-18 15:20:38+00:00
# クロスモーダル知覚痕跡モデルの学習に向けて
# c: 1100 	 2019-10-17 08:21:28+00:00
# 単一セルデータ上のクラスタリングのための専門家の変分省エンコーダおよび類似性表現から生成
# c: 1200 	 2019-10-15 20:47:29+00:00
# 遠い音声認識のための大規模受容電界畳込みネットワークの分析
# c: 1300 	 2019-10-14 16:42:09+00:00
# MTCNN顔検出システムへの実世界的利益攻撃
# c: 1400 	 2019-10-13 03:54:25+00:00
# ECNN：エッジ推論のためのブロックベースおよび高並列CNNアクセラレータ
# c: 1500 	 2019-10-11 12:14:22+00:00
# ABCDP：差動プライバシーによる近似ベイジアン計算
# c: 1600 	 2019-10-10 08:07:17+00:00
# 逆動力学の意見の相違を最小にすることによって観察からの模倣学習
# c: 1700 	 2019-10-09 04:13:51+00:00
# Ensemble Gaussianプロセス回帰を用いた電気負荷と電力予測
# c: 1800 	 2019-10-07 18:43:12+00:00
# 深いニューラルネットワークのためのビット効率の高い量子化
# c: 1900 	 2019-10-05 18:58:59+00:00
# ExpertMatcher：リソース制約国のユーザーのMLモデル選択の自動化
# c: 2000 	 2019-10-03 23:39:31+00:00
# 日本語単語セグメンテーションのための文字特徴エンジニアリング
# c: 2100 	 2019-10-02 16:33:51+00:00
# ストリーミングの非標識データに対する弱い監督によるコンセプトドリフトの検出と適応
# c: 2200 	 2019-10-01 12:13:04+00:00
# 機械学習法を用いた心不全の危険性がある癌患者を同定する
# query:cat:'cs.LG AND submittedDate:[20191101000000 TO 20191130235959]'
# c: 0 	 2019-11-30 23:57:48+00:00
# GPUクラスタ上の混合精度を有するディープリカレントニューラルネットワークを分散させるトレーニング
# c: 100 	 2019-11-29 01:40:54+00:00
# 都市全体の大気汚染補間と予測のための時空間深刻学習モデル
# c: 200 	 2019-11-27 17:01:07+00:00
# Comhapdet：ハプロタイプアセンブリのための空間コミュニティ検出アルゴリズム
# c: 300 	 2019-11-26 14:38:42+00:00
# 無作為化特異値分解
# c: 400 	 2019-11-25 10:12:10+00:00
# 構造情報を用いた深い双方向タンパク質配列表現の事前研修
# c: 500 	 2019-11-22 18:16:48+00:00
# Schrödinger-Ani：薬物様化学空間の大幅に拡大されたカバレッジを持つ8要素ニューラルネットワーク相互作用ポテンシャル
# c: 600 	 2019-11-21 16:32:14+00:00
# HVACの事前知識と組み合わせたマルチPCAベースの故障検出モデル
# c: 700 	 2019-11-20 16:22:22+00:00
# RパッケージABNを用いた加法的ベイジアンネットワークモデリング
# c: 800 	 2019-11-19 15:46:20+00:00
# $Δ$ Hindsightクレジット割り当てによる有利な推定の減少
# c: 900 	 2019-11-18 15:40:06+00:00
# ニューラルネットワークのオンライントレーニングのためのフィードバック制御
# c: 1000 	 2019-11-17 01:29:54+00:00
# 高精度医学の進歩における人工知能の機会
# c: 1100 	 2019-11-15 07:30:17+00:00
# 癌型分類のための深部識別微調整
# c: 1200 	 2019-11-13 18:17:38+00:00
# 収束オフポリシーの時間差アルゴリズム
# c: 1300 	 2019-11-12 15:35:39+00:00
# 汚れのないネットの永遠の日差し：ディープネットワークでの選択的忘却
# c: 1400 	 2019-11-11 11:03:53+00:00
# 組成階層テンソル因数分解：階層的な固有の因果的因果的要因を表す
# c: 1500 	 2019-11-09 19:18:19+00:00
# DevleARN：電力システムにおける一時的な障害を局在化するための深い視覚的学習フレームワーク
# c: 1600 	 2019-11-08 07:46:47+00:00
# 統一されたサンプル最適抵抗推定
# c: 1700 	 2019-11-06 17:25:53+00:00
# 高周波価格量データに基づく在庫選択のための深い学習
# c: 1800 	 2019-11-05 14:38:18+00:00
# スケッチによる連合学習のプライバシーを強化する
# c: 1900 	 2019-11-04 04:12:31+00:00
# T-SNEを用いた複数の動作条件での多目的スイッチドリラクタンス機の最適化の可視化
# c: 2000 	 2019-11-01 15:31:27+00:00
# ソーシャルネットワークにおける公正な治療の割り当て
# query:cat:'cs.LG AND submittedDate:[20191201000000 TO 20191231235959]'
# c: 0 	 2019-12-31 23:55:44+00:00
# 訓練された深部ニューラルネットワークからのダイナミクスの対称性を導出することによる解釈可能な保全法推定
# c: 100 	 2019-12-30 00:03:28+00:00
# 最適な不確実性ガイドナーラルネットワークトレーニング
# c: 200 	 2019-12-26 22:04:41+00:00
# 浅いRELUモデルにおける最小対称性の原則について
# c: 300 	 2019-12-23 23:05:04+00:00
# 頭頸部、肺癌および乳癌適応放射線療法のための単一のニューラルネットワークによるCBCT-TO-CT合成
# c: 400 	 2019-12-21 17:44:09+00:00
# 変分省電池における相互情報を最大にすることによって学習表現
# c: 500 	 2019-12-19 23:57:55+00:00
# コンテキスト対応推奨システムのためのガウスプロセス潜在的モデル因数分解
# c: 600 	 2019-12-18 15:35:38+00:00
# Sigma：GaNとメタリスティックスティックスティックスティックスの強化
# c: 700 	 2019-12-17 01:40:04+00:00
# 識別低ランク表現による共同表現に基づくロバスト顔認識
# c: 800 	 2019-12-14 16:58:51+00:00
# 株取引のためのマルチエージェント強化学習の公平性
# c: 900 	 2019-12-12 14:21:58+00:00
# 伝播経路のトレース：グラフ上の表現学習の流れの観点
# c: 1000 	 2019-12-11 07:48:49+00:00
# ベイジアン混合モデルのサンプリング：多項式 - 時間混合のMCMC
# c: 1100 	 2019-12-09 21:11:02+00:00
# Sharkovskyの定理を介したRELUネットワークのための深さ幅トレードオフ
# c: 1200 	 2019-12-07 14:30:22+00:00
# 運転スタイルのエンコーダ：自動運転における汎用計画のための状況報酬適応
# c: 1300 	 2019-12-05 18:54:23+00:00
# Qラーニングと償却数の推定値を検索する
# c: 1400 	 2019-12-04 18:32:15+00:00
# プラグアンドプレイ言語モデル：制御テキスト生成への簡単なアプローチ
# c: 1500 	 2019-12-03 09:11:25+00:00
# 周期的機能マッピング：非等尺性変形形状の間の自己監視対応
# c: 1600 	 2019-12-02 09:46:03+00:00
# 騒々しい、欲張り、それほど貪欲なk平均++
# query:cat:'cs.LG AND submittedDate:[20200101000000 TO 20200131235959]'
# c: 0 	 2020-01-31 23:50:03+00:00
# ノイズ除去自動エンコーダとLAGHEVINサンプリングによる生成モデリング
# c: 100 	 2020-01-30 13:58:49+00:00
# 構造機能ベースのグラフ自己適応プーリング
# c: 200 	 2020-01-28 18:59:03+00:00
# マージンランキング下の領域を使用した誤ラベル付きデータを識別する
# c: 300 	 2020-01-27 08:00:23+00:00
# 表面実装技術におけるリフロープロセス中の部品シフトのデータ駆動型予測モデル
# c: 400 	 2020-01-24 05:07:39+00:00
# ワイヤレスセキュリティが機械学習を満たすとき：動機づけ、課題、そして研究の方向
# c: 500 	 2020-01-22 16:14:38+00:00
# 償却された近似最大値を介した莫大な行動空間におけるQラーニング
# c: 600 	 2020-01-21 01:28:58+00:00
# DLGA-PDE：深部学習と遺伝的アルゴリズムの組み合わせによる不完全な候補ライブラリを有するPDEの発見
# c: 700 	 2020-01-17 15:25:44+00:00
# 起動関数の近似
# c: 800 	 2020-01-15 18:10:46+00:00
# ステータスQUO損失を用いたマルチエージェント補強学習を通じて逐次社会的ジレンマにおける協調行動の誘発
# c: 900 	 2020-01-14 10:42:45+00:00
# サイバー調査のための限られたネットワークトレースを用いたIoTネットワークの行動指紋推論メタ学習アプローチ
# c: 1000 	 2020-01-12 00:20:00+00:00
# 予測、一般化、再帰の基礎的な限界：エントロピー - イノベーションの観点
# c: 1100 	 2020-01-09 01:21:30+00:00
# ニューラルデータサーバ転送学習データの大規模検索エンジン
# c: 1200 	 2020-01-07 05:12:14+00:00
# 深部ニューラルネットワークを用いた高速およびロバスト多環単分子局在顕微鏡
# c: 1300 	 2020-01-04 09:31:11+00:00
# 皮膚病変画像のセグメンテーションと分類のための自己学習AIフレームワーク
# c: 1400 	 2020-01-01 03:35:10+00:00
# INF-VAE：拡散予測に均衡と影響を統合するための変分省電池フレームワーク
# query:cat:'cs.LG AND submittedDate:[20200201000000 TO 20200229235959]'
# c: 0 	 2020-02-29 23:50:08+00:00
# 一般コストと報酬分布に対する予算制約付き盗難
# c: 100 	 2020-02-28 10:02:58+00:00
# ROSAを実証する：あらゆるデータ分析パイプラインの公平性ソリューション
# c: 200 	 2020-02-27 08:26:34+00:00
# ノンスムースノンコンノベート関数のほぼ静止点を見つけることができますか？
# c: 300 	 2020-02-26 10:02:32+00:00
# 無限に広いグラフ畳み込みネットワーク：ガウスプロセスによる半監視学習
# c: 400 	 2020-02-25 08:27:41+00:00
# a.i.DeepSpeechを使用してテキストへの埋め込みスピーチ
# c: 500 	 2020-02-24 08:59:34+00:00
# 多くの武器を伴う多武装盗賊における欲張りアルゴリズムの不当な有効性
# c: 600 	 2020-02-22 15:07:20+00:00
# 一般化条件付き勾配法のための安全なスクリーニング
# c: 700 	 2020-02-21 09:09:59+00:00
# 最適ランダム化分類ツリーにおけるスパース性
# c: 800 	 2020-02-20 13:57:29+00:00
# アプリケーションのクリックストリームデータを使用した顧客行動分析のためのグラフベースのプラットフォーム
# c: 900 	 2020-02-19 15:45:41+00:00
# シャッフル型勾配法のための統合コンバージェンス解析
# c: 1000 	 2020-02-18 15:40:13+00:00
# 自己回帰構造化予測における不確実性推定
# c: 1100 	 2020-02-17 08:38:51+00:00
# バッチ補強学習における行動持続による制御周波数適応
# c: 1200 	 2020-02-15 09:29:36+00:00
# 強く抱きしめて！ディープネットワーク境界に対する識別機能の影響
# c: 1300 	 2020-02-14 00:00:03+00:00
# ポイントセットカーネルに基づくクラスタリング
# c: 1400 	 2020-02-12 21:46:22+00:00
# プライバシーポリシーカバレッジ分析のためのシーケンス分類モデルの比較研究
# c: 1500 	 2020-02-11 22:52:40+00:00
# スーパーブローム：ブルームフィルターは変圧器を満たしています
# c: 1600 	 2020-02-10 23:07:53+00:00
# 車両テレマティクスでの操縦モチーフを見つけること
# c: 1700 	 2020-02-10 03:27:48+00:00
# 自問協会記憶
# c: 1800 	 2020-02-08 05:53:21+00:00
# 敵対的透かしを伴う光学文字認識（OCR）システム
# c: 1900 	 2020-02-07 03:08:31+00:00
# 深部ニューラルネットワークを用いた高次元固有値問題の解法：アプローチのような拡散モンテカルロ
# c: 2000 	 2020-02-05 21:27:06+00:00
# 明示的な機能マップとしてのネストされた重心座標系
# c: 2100 	 2020-02-04 06:22:24+00:00
# EEG信号を用いたてんかん発作を予測するための機械学習：レビュー
# c: 2200 	 2020-02-02 18:21:22+00:00
# 自律運転のための深い強化学習調査
# query:cat:'cs.LG AND submittedDate:[20200301000000 TO 20200331235959]'
# c: 0 	 2020-03-31 23:51:27+00:00
# 瞬間問題のカーネル平均埋め込みを用いた分散曖昧さの下での最悪のリスク定量化
# c: 100 	 2020-03-30 18:23:26+00:00
# ゴシップと出席：状況依存グラフ表現学習
# c: 200 	 2020-03-29 04:23:22+00:00
# デュアルマルチラベル予測による適応オブジェクト検出
# c: 300 	 2020-03-26 22:06:18+00:00
# プロセスモデルの一般化を定量化するための敵対的なシステム変種近似
# c: 400 	 2020-03-25 08:31:28+00:00
# 生成敵対的ネットを介した予測ビジネスプロセス監視：次回のイベント予測の場合
# c: 500 	 2020-03-23 20:41:51+00:00
# ニューロリング構造のためのデータ駆動モデルと計算ツール言語技術の観点
# c: 600 	 2020-03-21 16:26:59+00:00
# 非アクティブなスキップ接続を持つクロスモーダルディープフェイスノルマル
# c: 700 	 2020-03-19 17:56:41+00:00
# DELTAS：三角測量の学習とスパースポイントの緻密化による深さ推定
# c: 800 	 2020-03-18 01:51:42+00:00
# CHANTERSTRESS：ビッグデータMLのユースケースのための自律雲 - ノードスコープフレームワーク
# c: 900 	 2020-03-16 16:27:49+00:00
# CLDICE  - 管状構造セグメンテーションのための新しいトポロジー保存損失関数
# c: 1000 	 2020-03-13 19:40:57+00:00
# 法的手続の状況の予測：順次テキストデータに基づくアプローチ
# c: 1100 	 2020-03-12 03:18:59+00:00
# 2D画像空間で3D点群をセグメント化することを学ぶ
# c: 1200 	 2020-03-10 10:34:30+00:00
# 形状変形のためのコンパクトなスペクトル記述子
# c: 1300 	 2020-03-09 05:12:39+00:00
# バッチ補強学習のためのq *近似スキーム理論的比較
# c: 1400 	 2020-03-06 21:01:44+00:00
# 干渉位相復元のための複素ドメインに対する畳込みスパース符号化の学習
# c: 1500 	 2020-03-05 13:19:13+00:00
# AIはあらゆる皮膚科医に上昇した：最適化された深いCNNアーキテクチャにおけるバッチ論理および損失関数のカスタマイズによる脳鏡下メラノーマ診断の改善
# c: 1600 	 2020-03-04 04:43:16+00:00
# メタ周期アニーリングスケジュール：メタ償却誤差を回避するための簡単なアプローチ
# c: 1700 	 2020-03-02 23:37:42+00:00
# 無作為化スムージングの隠されたコスト
# c: 1800 	 2020-03-01 21:01:59+00:00
# 消費電力データのオンライン階層予測
# query:cat:'cs.LG AND submittedDate:[20200401000000 TO 20200430235959]'
# c: 0 	 2020-04-30 23:58:03+00:00
# 大規模タイピングによる解釈可能エンティティ表現
# c: 100 	 2020-04-29 21:27:26+00:00
# 感じるようにカメラを教える：画像からの表面の触覚物性の推定
# c: 200 	 2020-04-28 15:55:16+00:00
# リニア仮説とニューラルネットワークのための敵対的な学習保証
# c: 300 	 2020-04-27 12:59:22+00:00
# 重心の自動溶融階層ファジィCを意味するクラスタリング
# c: 400 	 2020-04-25 17:52:05+00:00
# ネットワークラソを用いたローカルグラフクラスタリング
# c: 500 	 2020-04-24 03:03:21+00:00
# スパースニューラルネットワークのための非偏心ペナルティ化
# c: 600 	 2020-04-22 17:25:46+00:00
# 等しく制限された二次プログラミングにおけるQの嵌合解除
# c: 700 	 2020-04-21 08:55:55+00:00
# MixNet：脳セグメンテーションのためのマルチモダリティミックスネットワーク
# c: 800 	 2020-04-20 09:29:03+00:00
# 合理的スペクトルの間の新しい測定基準と最適輸送への接続
# c: 900 	 2020-04-17 16:42:18+00:00
# ベイジアン隠しマルコフモデルにおける地図セグメンテーション：ケーススタディ
# c: 1000 	 2020-04-16 04:28:08+00:00
# ジョブの適切なツール：マッチングモデルとインスタンスの複雑さ
# c: 1100 	 2020-04-14 17:23:37+00:00
# 神経算術論理ユニットを備えたセル画像上のより良いインスタンスカウントモデルを体系的に設計する
# c: 1200 	 2020-04-13 09:01:49+00:00
# 推論から世代まで：スピーチからの人間の顔の完全に自己学習された生成
# c: 1300 	 2020-04-11 00:56:36+00:00
# 習得不確実性を持つロバスト制御バリア関数による安全なマルチエージェント相互作用
# c: 1400 	 2020-04-09 14:13:20+00:00
# SpatialSim：グラフニューラルネットワークを用いたオブジェクトの空間構成の認識
# c: 1500 	 2020-04-08 03:45:48+00:00
# マルチエージェントマルチアーム帯域の問題に対する動的観測戦略
# c: 1600 	 2020-04-06 20:46:37+00:00
# NILBS：ニューラルインバースリニアブレンドスキン
# c: 1700 	 2020-04-05 15:51:31+00:00
# 一般化されたゼロショット学習からクラス記述子との長テイルへ
# c: 1800 	 2020-04-03 13:51:10+00:00
# TRAMP：ツリー近似メッセージ通過による構成推論
# c: 1900 	 2020-04-01 18:06:21+00:00
# IGBO-English Machine翻訳：評価ベンチマーク
# query:cat:'cs.LG AND submittedDate:[20200501000000 TO 20200531235959]'
# c: 0 	 2020-05-31 23:58:43+00:00
# ゲート付き再発ユニットと注意メカニズムを備えた歩行者追跡
# c: 100 	 2020-05-29 17:35:23+00:00
# データ駆動型バイオメカニカルモデルを用いた表面位置合わせに対する非剛体容積
# c: 200 	 2020-05-28 01:33:07+00:00
# AIおよびHPC対応のリード生成でSARS-COV-2をターゲットにする：最初のデータリリース
# c: 300 	 2020-05-26 16:33:52+00:00
# COVID-NET S：地理的範囲と不透明度のための深いニューラルネットワークの訓練と検証によるコンピュータ支援重症度評価に向けて、SARS-COV-2肺疾患の重症度のための胸部X線の採点
# c: 400 	 2020-05-25 01:10:01+00:00
# 深部ニューラルネットワークを訓練するための分数モーメント保存初期化スキーム
# c: 500 	 2020-05-22 12:44:16+00:00
# 量子自己審査装置の圧縮率について：制御設計、数値的および実験的実験
# c: 600 	 2020-05-21 01:46:59+00:00
# 未活性化ソフトロボットの手の動的モデルを転送することを学ぶ
# c: 700 	 2020-05-19 17:57:29+00:00
# 自動音声認識のための騒々しい学生訓練の改善
# c: 800 	 2020-05-18 16:46:13+00:00
# 深い暗黙の音量圧縮
# c: 900 	 2020-05-16 20:08:04+00:00
# 自動マルチラベル分類法のロバスト実験的評価
# c: 1000 	 2020-05-15 11:25:08+00:00
# 精神障害オンラインコミュニティにおけるユーザの感情的な調子の予測
# c: 1100 	 2020-05-13 17:21:27+00:00
# リレーショナルデータベースの埋め込みについて
# c: 1200 	 2020-05-12 07:53:35+00:00
# Centaur：パーソナライズされた推奨事項のためのキプライプレスベースのハイブリッドスパース密なアクセラレータ
# c: 1300 	 2020-05-10 21:27:38+00:00
# 代表学習への監督とソースドメインの影響：病理組織学的事例研究
# c: 1400 	 2020-05-08 16:24:55+00:00
# 敵対的な知識蒸留によるデータのないネットワーク量子化
# c: 1500 	 2020-05-07 12:16:38+00:00
# LINKSIQ：不完全なスペクトルスキャンによる堅牢で効率的な変調認識
# c: 1600 	 2020-05-06 01:40:26+00:00
# 特徴ピラミッドデコーダによる固有の敵対的堅牢性の向上
# c: 1700 	 2020-05-04 17:22:44+00:00
# PPG2ABP：完全畳み込みニューラルネットワークを用いた動脈血圧（ABP）波形への光透過性（PPG）信号の変換
# c: 1800 	 2020-05-02 15:53:33+00:00
# Minerva：伝統的なエンタープライズSaaSアプリケーションのための携帯機械学習ミクロサービスフレームワーク
# c: 1900 	 2020-05-01 06:58:18+00:00
# Webスケール言語報道のためのピボット安定化を用いたクロスモーダル言語生成
# query:cat:'cs.LG AND submittedDate:[20200601000000 TO 20200630235959]'
# c: 0 	 2020-06-30 23:53:12+00:00
# 半監視された逐次生成モデル
# c: 100 	 2020-06-30 05:28:23+00:00
# 理論 - インスパイアパス正則化差分ネットワークアーキテクチャ検索
# c: 200 	 2020-06-29 09:38:54+00:00
# ハード2Dタスクのためのマトリックスシャッフル交換ネットワーク
# c: 300 	 2020-06-27 16:49:37+00:00
# 複合物理層を用いた学習センシングネットワークによる多要素顕微鏡最適化
# c: 400 	 2020-06-26 07:20:15+00:00
# 線形プログラミングによる集合の共分散係合分類
# c: 500 	 2020-06-25 07:38:00+00:00
# Praphraseの世代のニューラルマシン翻訳
# c: 600 	 2020-06-24 11:40:36+00:00
# 標準有限幅畳み込みニューラルネットワークアーキテクチャの経験的神経接線核
# c: 700 	 2020-06-23 16:06:52+00:00
# 悪化した学習を通じて人口統計のない公平性
# c: 800 	 2020-06-22 17:55:59+00:00
# 自己監視ビデオオブジェクトセグメンテーション
# c: 900 	 2020-06-22 03:20:36+00:00
# COVID-19画像データ収集：前向き予測は未来です
# c: 1000 	 2020-06-20 13:40:27+00:00
# 複合凸およびスムーズな最適化のための確率勾配法の統一分析
# c: 1100 	 2020-06-19 07:35:25+00:00
# ドメインシフトによる医療画像セグメンテーションにおける破損ラベルに対するクロスノイズ除去ネットワーク
# c: 1200 	 2020-06-18 14:50:08+00:00
# ブロックチェーンを用いたIOTの軽量共同異常検出
# c: 1300 	 2020-06-17 19:18:22+00:00
# 距離意識を介した決定論的深部学習によるシンプルで原則的な不確実性推定
# c: 1400 	 2020-06-17 05:32:14+00:00
# XRAYGAN：放射線学レポートからのX線画像の一貫性保存生成
# c: 1500 	 2020-06-16 15:49:21+00:00
# 運転行動の半監視分類によるIMU信号のデータ増強と評価
# c: 1600 	 2020-06-16 01:24:21+00:00
# ユニバーサル近似の最小幅
# c: 1700 	 2020-06-15 13:23:34+00:00
# TOEPLITZマトリックス理論を用いた畳み込み層のLipschitzの正則化について
# c: 1800 	 2020-06-14 14:22:59+00:00
# マクロ経済変化に基づく損失予測フレームワーク：米国のクレジットカード業界への応用
# c: 1900 	 2020-06-13 01:48:15+00:00
# FakePolisher：浅い再建によってより多くの検出をより検出 - 回避する
# c: 2000 	 2020-06-12 13:17:25+00:00
# 私たちはImagenetをやっていますか？
# c: 2100 	 2020-06-11 21:35:24+00:00
# ソースコードのニューラルモデルのバックドア
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# <ipython-input-8-4d009027c958> in <module>
# ----> 1 getter_by_mounth( datetime.datetime(2010, 1, 1), datetime.datetime.now(), category="cs.LG")
#
# <ipython-input-7-4e149badcccd> in getter_by_mounth(start_dt, end_dt, category)
#       8         current_month_top_str = get_str_datetime__only_numerical_value( get_datetime_month_top(current_month) )
#       9         current_month_tail_str = get_str_datetime__only_numerical_value( get_datetime_month_tail(current_month) )
# ---> 10         get_by_submitted_date(current_month_top_str, current_month_tail_str, category, base_path=base_path)
#      11
#      12         current_month = get_datetime_next_month(current_month)
#
# <ipython-input-4-7547fdd917fc> in get_by_submitted_date(start_date, end_date, category, base_path)
#      36             abst = abst.replace("\n","")
#      37
# ---> 38             title_jp =  str(translator.translate(title, src='en' ,dest='ja').text)
#      39             abst_jp =  str(translator.translate(abst, src='en' ,dest='ja').text)
#      40
#
# ~/.local/lib/python3.8/site-packages/googletrans/client.py in translate(self, text, dest, src)
#     192
#     193         origin = text
# --> 194         data, response = self._translate(text, dest, src)
#     195
#     196         token_found = False
#
# ~/.local/lib/python3.8/site-packages/googletrans/client.py in _translate(self, text, dest, src)
#     118             'rt': 'c',
#     119         }
# --> 120         r = self.client.post(url, params=params, data=data)
#     121
#     122         if r.status_code != 200 and self.raise_Exception:
#
# /usr/local/lib/python3.8/dist-packages/httpx/_client.py in post(self, url, data, files, json, params, headers, cookies, auth, allow_redirects, timeout)
#     822         timeout: typing.Union[TimeoutTypes, UnsetType] = UNSET,
#     823     ) -> Response:
# --> 824         return self.request(
#     825             "POST",
#     826             url,
#
# /usr/local/lib/python3.8/dist-packages/httpx/_client.py in request(self, method, url, data, files, json, params, headers, cookies, auth, allow_redirects, timeout)
#     598             cookies=cookies,
#     599         )
# --> 600         return self.send(
#     601             request, auth=auth, allow_redirects=allow_redirects, timeout=timeout,
#     602         )
#
# /usr/local/lib/python3.8/dist-packages/httpx/_client.py in send(self, request, stream, auth, allow_redirects, timeout)
#     618         auth = self.build_auth(request, auth)
#     619
# --> 620         response = self.send_handling_redirects(
#     621             request, auth=auth, timeout=timeout, allow_redirects=allow_redirects,
#     622         )
#
# /usr/local/lib/python3.8/dist-packages/httpx/_client.py in send_handling_redirects(self, request, auth, timeout, allow_redirects, history)
#     645                 raise TooManyRedirects()
#     646
# --> 647             response = self.send_handling_auth(
#     648                 request, auth=auth, timeout=timeout, history=history
#     649             )
#
# /usr/local/lib/python3.8/dist-packages/httpx/_client.py in send_handling_auth(self, request, history, auth, timeout)
#     682         request = next(auth_flow)
#     683         while True:
# --> 684             response = self.send_single_request(request, timeout)
#     685             if auth.requires_response_body:
#     686                 response.read()
#
# /usr/local/lib/python3.8/dist-packages/httpx/_client.py in send_single_request(self, request, timeout)
#     712                 headers,
#     713                 stream,
# --> 714             ) = transport.request(
#     715                 request.method.encode(),
#     716                 request.url.raw,
#
# /usr/local/lib/python3.8/dist-packages/httpcore/_sync/connection_pool.py in request(self, method, url, headers, stream, timeout)
#     150
#     151             try:
# --> 152                 response = connection.request(
#     153                     method, url, headers=headers, stream=stream, timeout=timeout
#     154                 )
#
# /usr/local/lib/python3.8/dist-packages/httpcore/_sync/connection.py in request(self, method, url, headers, stream, timeout)
#      63                         "open_socket origin=%r timeout=%r", self.origin, timeout
#      64                     )
# ---> 65                     self.socket = self._open_socket(timeout)
#      66                 self._create_connection(self.socket)
#      67             elif self.state in (ConnectionState.READY, ConnectionState.IDLE):
#
# /usr/local/lib/python3.8/dist-packages/httpcore/_sync/connection.py in _open_socket(self, timeout)
#      83         ssl_context = self.ssl_context if scheme == b"https" else None
#      84         try:
# ---> 85             return self.backend.open_tcp_stream(
#      86                 hostname, port, ssl_context, timeout
#      87             )
#
# /usr/local/lib/python3.8/dist-packages/httpcore/_backends/sync.py in open_tcp_stream(self, hostname, port, ssl_context, timeout)
#     137                     sock, server_hostname=hostname.decode("ascii")
#     138                 )
# --> 139             return SyncSocketStream(sock=sock)
#     140
#     141     def create_lock(self) -> SyncLock:
#
# /usr/lib/python3.8/contextlib.py in __exit__(self, type, value, traceback)
#     129                 value = type()
#     130             try:
# --> 131                 self.gen.throw(type, value, traceback)
#     132             except StopIteration as exc:
#     133                 # Suppress StopIteration *unless* it's the same exception that
#
# /usr/local/lib/python3.8/dist-packages/httpcore/_exceptions.py in map_exceptions(map)
#      10         for from_exc, to_exc in map.items():
#      11             if isinstance(exc, from_exc):
# ---> 12                 raise to_exc(exc) from None
#      13         raise
#      14
#
# ConnectError: [Errno 101] Network is unreachable

# %%
getter_by_mounth( datetime.datetime(2020, 5, 1), datetime.datetime.now(), category="cs.LG")
# Out:
# query:cat:'cs.LG AND submittedDate:[20200501000000 TO 20200531235959]'
# c: 0 	 2020-05-31 23:58:43+00:00
# ゲート付き再発ユニットと注意メカニズムを備えた歩行者追跡
# c: 100 	 2020-05-29 17:35:23+00:00
# データ駆動型バイオメカニカルモデルを用いた表面位置合わせに対する非剛体容積
# c: 200 	 2020-05-28 01:33:07+00:00
# AIおよびHPC対応のリード生成でSARS-COV-2をターゲットにする：最初のデータリリース
# c: 300 	 2020-05-26 16:33:52+00:00
# COVID-NET S：地理的範囲と不透明度のための深いニューラルネットワークの訓練と検証によるコンピュータ支援重症度評価に向けて、SARS-COV-2肺疾患の重症度のための胸部X線の採点
# c: 400 	 2020-05-25 01:10:01+00:00
# 深部ニューラルネットワークを訓練するための分数モーメント保存初期化スキーム
# c: 500 	 2020-05-22 12:44:16+00:00
# 量子自己審査装置の圧縮率について：制御設計、数値的および実験的実験
# c: 600 	 2020-05-21 01:46:59+00:00
# 未活性化ソフトロボットの手の動的モデルを転送することを学ぶ
# c: 700 	 2020-05-19 17:57:29+00:00
# 自動音声認識のための騒々しい学生訓練の改善
# c: 800 	 2020-05-18 16:46:13+00:00
# 深い暗黙の音量圧縮
# c: 900 	 2020-05-16 20:08:04+00:00
# 自動マルチラベル分類法のロバスト実験的評価
# c: 1000 	 2020-05-15 11:25:08+00:00
# 精神障害オンラインコミュニティにおけるユーザの感情的な調子の予測
# c: 1100 	 2020-05-13 17:21:27+00:00
# リレーショナルデータベースの埋め込みについて
# c: 1200 	 2020-05-12 07:53:35+00:00
# Centaur：パーソナライズされた推奨事項のためのキプライプレスベースのハイブリッドスパース密なアクセラレータ
# c: 1300 	 2020-05-10 21:27:38+00:00
# 代表学習への監督とソースドメインの影響：病理組織学的事例研究
# c: 1400 	 2020-05-08 16:24:55+00:00
# 敵対的な知識蒸留によるデータのないネットワーク量子化
# c: 1500 	 2020-05-07 12:16:38+00:00
# LINKSIQ：不完全なスペクトルスキャンによる堅牢で効率的な変調認識
# c: 1600 	 2020-05-06 01:40:26+00:00
# 特徴ピラミッドデコーダによる固有の敵対的堅牢性の向上
# c: 1700 	 2020-05-04 17:22:44+00:00
# PPG2ABP：完全畳み込みニューラルネットワークを用いた動脈血圧（ABP）波形への光透過性（PPG）信号の変換
# c: 1800 	 2020-05-02 15:53:33+00:00
# Minerva：伝統的なエンタープライズSaaSアプリケーションのための携帯機械学習ミクロサービスフレームワーク
# c: 1900 	 2020-05-01 06:58:18+00:00
# Webスケール言語報道のためのピボット安定化を用いたクロスモーダル言語生成
# query:cat:'cs.LG AND submittedDate:[20200601000000 TO 20200630235959]'
# c: 0 	 2020-06-30 23:53:12+00:00
# 半監視された逐次生成モデル
# c: 100 	 2020-06-30 05:28:23+00:00
# 理論 - インスパイアパス正則化差分ネットワークアーキテクチャ検索
# c: 200 	 2020-06-29 09:38:54+00:00
# ハード2Dタスクのためのマトリックスシャッフル交換ネットワーク
# c: 300 	 2020-06-27 16:49:37+00:00
# 複合物理層を用いた学習センシングネットワークによる多要素顕微鏡最適化
# c: 400 	 2020-06-26 07:20:15+00:00
# 線形プログラミングによる集合の共分散係合分類
# c: 500 	 2020-06-25 07:38:00+00:00
# Praphraseの世代のニューラルマシン翻訳
# c: 600 	 2020-06-24 11:40:36+00:00
# 標準有限幅畳み込みニューラルネットワークアーキテクチャの経験的神経接線核
# c: 700 	 2020-06-23 16:06:52+00:00
# 悪化した学習を通じて人口統計のない公平性
# c: 800 	 2020-06-22 17:55:59+00:00
# 自己監視ビデオオブジェクトセグメンテーション
# c: 900 	 2020-06-22 03:20:36+00:00
# COVID-19画像データ収集：前向き予測は未来です
# c: 1000 	 2020-06-20 13:40:27+00:00
# 複合凸およびスムーズな最適化のための確率勾配法の統一分析
# c: 1100 	 2020-06-19 07:35:25+00:00
# ドメインシフトによる医療画像セグメンテーションにおける破損ラベルに対するクロスノイズ除去ネットワーク
# c: 1200 	 2020-06-18 14:50:08+00:00
# ブロックチェーンを用いたIOTの軽量共同異常検出
# c: 1300 	 2020-06-17 19:18:22+00:00
# 距離意識を介した決定論的深部学習によるシンプルで原則的な不確実性推定
# c: 1400 	 2020-06-17 05:32:14+00:00
# XRAYGAN：放射線学レポートからのX線画像の一貫性保存生成
# c: 1500 	 2020-06-16 15:49:21+00:00
# 運転行動の半監視分類によるIMU信号のデータ増強と評価
# c: 1600 	 2020-06-16 01:24:21+00:00
# ユニバーサル近似の最小幅
# c: 1700 	 2020-06-15 13:23:34+00:00
# TOEPLITZマトリックス理論を用いた畳み込み層のLipschitzの正則化について
# c: 1800 	 2020-06-14 14:22:59+00:00
# マクロ経済変化に基づく損失予測フレームワーク：米国のクレジットカード業界への応用
# c: 1900 	 2020-06-13 01:48:15+00:00
# FakePolisher：浅い再建によってより多くの検出をより検出 - 回避する
# c: 2000 	 2020-06-12 13:17:25+00:00
# 私たちはImagenetをやっていますか？
# c: 2100 	 2020-06-11 21:35:24+00:00
# ソースコードのニューラルモデルのバックドア
# c: 2200 	 2020-06-11 12:48:03+00:00
# 分散オンライン学習を備えた広いグラフニューラルネットワーク
# c: 2300 	 2020-06-10 16:16:01+00:00
# クラウド検出のためのLandsat-8とProba-V画像のクロスセンサーの敵対的領域適応
# c: 2400 	 2020-06-09 19:59:29+00:00
# おそらくほぼ正しい制約の学習
# c: 2500 	 2020-06-09 03:22:33+00:00
# マルチクラスの教育データマイニングのためのマルチスプリット最適化されたバッグアンサンブルモデル選択
# c: 2600 	 2020-06-08 14:26:45+00:00
# モデル - 特長による重要度と効果 - 条件付きサブグループアプローチ
# c: 2700 	 2020-06-07 13:38:32+00:00
# BERTは忍耐力を失う：早い出口の高速で堅牢な推論
# c: 2800 	 2020-06-05 22:25:27+00:00
# 関係の関係：関係抽出問題の新しいパラダイム
# c: 2900 	 2020-06-05 02:04:25+00:00
# COVID-19発生整列化のためのクロスリング転送学習
# c: 3000 	 2020-06-03 21:00:11+00:00
# フィルタリング転送学習を用いたラベル信頼配布を越えて学ぶこと
# c: 3100 	 2020-06-02 17:08:59+00:00
# 三次元（3D）グラフにおける深い学習のための幾何学的グラフ表現と幾何学的グラフ畳み込み
# c: 3200 	 2020-06-01 16:28:25+00:00
# DPDNet：オーバーヘッド深さカメラで深い学習を用いた堅牢な人々の検出器
# query:cat:'cs.LG AND submittedDate:[20200701000000 TO 20200731235959]'
# c: 0 	 2020-07-31 23:52:58+00:00
# 深部ニューラルネットワークのノイズ応答解析は、堅牢性と指紋構造マルウェアを定量化する
# c: 100 	 2020-07-30 17:29:00+00:00
# 複雑な依存構造の下での太陽可変選択比較の精度と安定性
# c: 200 	 2020-07-29 07:20:06+00:00
# 条件付き生成敵対的ネットワークによるCOVID-19 CT画像合成
# c: 300 	 2020-07-27 21:16:51+00:00
# リファクタリングと補間による代理損失の統一フレームワーク
# c: 400 	 2020-07-26 12:58:34+00:00
# アンダーサンプルMRイメージングのための関節再構成とバイアス場補正
# c: 500 	 2020-07-24 13:53:04+00:00
# 回転したフーリエ変換の間のドット製品の短い文字
# c: 600 	 2020-07-23 02:05:03+00:00
# Pareco：スリム可能なニューラルネットワークのためのパレート認識チャネル最適化
# c: 700 	 2020-07-21 14:06:59+00:00
# Semeval-2020のNewsSweeperタスク11：宣伝用のコンテキスト認識豊富な機能表現
# c: 800 	 2020-07-20 13:56:14+00:00
# ロバストな照明推定のためのモンテカルロドロップアウトアンサンブル
# c: 900 	 2020-07-18 17:11:20+00:00
# 眼底写真を介した糖尿病性網膜症の分類：疾患検出を高速化するための深い学習アプローチの利用
# c: 1000 	 2020-07-17 04:01:56+00:00
# コンテキスト化はグラデーションベースのメタラーチを強化します
# c: 1100 	 2020-07-16 06:02:18+00:00
# 信頼性の高い不確実性推定を伴う変分母エンコーダによる分布外サンプルの検出
# c: 1200 	 2020-07-15 06:05:37+00:00
# 測定誤差モデル：ノンパラメトリック法からディープニューラルネットワークへ
# c: 1300 	 2020-07-14 04:31:28+00:00
# 非線形ロバスト制御のための三元政策反復アルゴリズム
# c: 1400 	 2020-07-13 07:54:20+00:00
# PROTTRANS：自己監視型ディープラーニングと高性能コンピューティングを通じて、人生のコードの言語の割れに向けて
# c: 1500 	 2020-07-11 12:17:40+00:00
# XGBoostの機能の相互作用
# c: 1600 	 2020-07-10 04:28:43+00:00
# 差動プライベートな単純な線形回帰
# c: 1700 	 2020-07-09 01:58:28+00:00
# 単語埋め込みの文化的な地図作成
# c: 1800 	 2020-07-07 19:44:14+00:00
# 強化学習のためのオフライン政策評価における最適有意な均一統一収束
# c: 1900 	 2020-07-07 00:14:30+00:00
# AFROBEATSを予測するSpotifyデータを使用して曲をヒットします
# c: 2000 	 2020-07-06 03:16:13+00:00
# 多項式しきい値関数の重みと密度範囲について
# c: 2100 	 2020-07-03 18:33:23+00:00
# 収益最適化のためのモデル蒸留：解釈可能なパーソナライズされた価格設定
# c: 2200 	 2020-07-02 17:59:05+00:00
# すべての非標識データが等しいわけではありません：半監視学習における重みデータへの学習
# c: 2300 	 2020-07-01 19:25:34+00:00
# CONOC：ニューラルネットワークへのトロイの木馬攻撃に対するコンテンツフォーカス保護
# query:cat:'cs.LG AND submittedDate:[20200801000000 TO 20200831235959]'
# c: 0 	 2020-08-31 23:40:26+00:00
# GIF：生成解釈可能な顔
# c: 100 	 2020-08-29 05:19:32+00:00
# 多目的ベースの超軽量画像超解像度
# c: 200 	 2020-08-27 14:28:18+00:00
# ディープフォリオ：限界注文書データを用いたポートフォリオ用畳み込みニューラルネットワーク
# c: 300 	 2020-08-26 03:36:07+00:00
# モデルの勾配多様性を低減することによる半監視連合学習の改善
# c: 400 	 2020-08-24 21:05:27+00:00
# 翻訳としてのパッチング：データと比喩
# c: 500 	 2020-08-22 15:41:59+00:00
# Hi-CI：高次元における深い原因推論
# c: 600 	 2020-08-20 18:18:49+00:00
# 01の損失ニューラルネットワークを用いた敵対的堅牢性に向けて
# c: 700 	 2020-08-19 06:46:35+00:00
# ゼロショット学習のための属性プロトタイプネットワーク
# c: 800 	 2020-08-17 23:14:45+00:00
# プライバシー保護機能選択：調査と新しいプロトコルセットを提案する
# c: 900 	 2020-08-16 09:53:21+00:00
# 分散DNNトレーニングのためのドメイン固有の通信最適化
# c: 1000 	 2020-08-14 00:23:21+00:00
# アフィンreLU関数の局所Lipschitz定数の解析的境界
# c: 1100 	 2020-08-12 15:29:11+00:00
# 生成データ増強による微粒子画像分類器の性能の改善
# c: 1200 	 2020-08-11 06:38:53+00:00
# 深強化学習による降圧DC  -  DCコンバータのためのインテリジェント制御戦略
# c: 1300 	 2020-08-08 22:47:12+00:00
# 自動話者検証のための話題の変動を処理するための可変フレームレートベースのデータ増強
# c: 1400 	 2020-08-07 06:24:22+00:00
# 分解可能な構造を考慮した多周辺最適輸送問題のための多項式 - 時間アルゴリズム
# c: 1500 	 2020-08-05 17:48:00+00:00
# 地域提案インタラクションネットワークを用いた長期的な視覚的動力学の学習
# c: 1600 	 2020-08-04 13:44:50+00:00
# TOAD-GAN：一例からのコヒーレントスタイルレベル生成
# c: 1700 	 2020-08-02 23:05:02+00:00
# オーディオライム：ソース分離を使用した聴取不可能な説明
# query:cat:'cs.LG AND submittedDate:[20200901000000 TO 20200930235959]'
# c: 0 	 2020-09-30 23:33:11+00:00
# スマートビルディングでの乗員追跡に関するプライバシーに関する懸念
# c: 100 	 2020-09-29 22:54:30+00:00
# Stock 2vec：表現学習と時間的畳込みネットワークを用いた株式市場予測のためのハイブリッド深部学習枠組
# c: 200 	 2020-09-28 18:51:52+00:00
# サンプル効率的探査のための表現スペースでのノベルティ検索
# c: 300 	 2020-09-27 13:02:33+00:00
# スペクトル仮想診断を用いた電子ビーム縦特性の正確で自信を持って予測する
# c: 400 	 2020-09-25 07:52:19+00:00
# 同様の機能を備えたデータセットの機能選択の安定性のための調整された尺度
# c: 500 	 2020-09-23 20:02:00+00:00
# 積分二次制約を介した滑らかなゲームのための一次法の統一された解析
# c: 600 	 2020-09-22 14:32:42+00:00
# 体重集約ロジックによって記述された学習概念
# c: 700 	 2020-09-21 04:13:34+00:00
# 分散差動プライバシーと明確な要素を数える
# c: 800 	 2020-09-18 18:59:00+00:00
# 表現型特性を用いた確率的にサンプリングされたスペクトル的にクラスタ化された植物遺伝子型
# c: 900 	 2020-09-17 09:23:36+00:00
# 効率的な深部ニューラルネットワークのためのホリスティックフィルター剪定
# c: 1000 	 2020-09-16 03:54:12+00:00
# ゼロショット学習のための情報ボトルネック制約付き潜在的双方向埋め込み
# c: 1100 	 2020-09-14 17:17:49+00:00
# グループ教師付き学習によるゼロショット合成
# c: 1200 	 2020-09-12 16:06:58+00:00
# MELIME：機械学習モデルのための有意義な地元の説明
# c: 1300 	 2020-09-10 16:48:19+00:00
# 多施設MR画像における白質超表面セグメンテーションのためのサイクルガンによる教師なしドメイン適応
# c: 1400 	 2020-09-09 06:14:59+00:00
# 他の技術との知識蒸留の直交性について：アンサンブルの観点から見る
# c: 1500 	 2020-09-07 13:55:45+00:00
# SUNNY-AS2：アルゴリズムの選択のための日当たりの強化
# c: 1600 	 2020-09-05 04:58:06+00:00
# クラスタ化されていない帯域の統合
# c: 1700 	 2020-09-03 06:03:30+00:00
# 残余ネットワークのための実用的な層並列訓練アルゴリズム
# c: 1800 	 2020-09-01 15:08:23+00:00
# データの不確実性を持つグラフ埋め込み
# query:cat:'cs.LG AND submittedDate:[20201001000000 TO 20201031235959]'
# c: 0 	 2020-10-31 23:18:15+00:00
# サイバー物理システムのための論理校正不確実性を伴う予測監視
# c: 100 	 2020-10-30 10:10:08+00:00
# インテリジェントエッジデバイスでの深部学習を最適化するためのフュージョン触媒プルーニング
# c: 200 	 2020-10-29 09:03:18+00:00
# 深部学習を用いたハッブル宇宙望遠鏡画像における小惑星道の検出
# c: 300 	 2020-10-28 08:31:40+00:00
# 自然言語処理と機械学習技術を採用した知識グラフの生成
# c: 400 	 2020-10-27 08:51:30+00:00
# 選択的分類は、グループ間の格差を拡大することができます
# c: 500 	 2020-10-26 11:32:08+00:00
# K-NNベースのモード推定の複雑さのクエリ
# c: 600 	 2020-10-24 18:45:15+00:00
# グラフニューラルネットワークを用いた時間、天候および位置特異性に基づく道路事故の動向指標
# c: 700 	 2020-10-23 17:23:26+00:00
# 予想最大化アルゴリズムから自己復元変分ベイエスまで
# c: 800 	 2020-10-22 20:40:44+00:00
# 深い画像のプラリを使用して反機能説明を生成します
# c: 900 	 2020-10-22 11:17:18+00:00
# ロボット貪法挙動の定量分析
# c: 1000 	 2020-10-21 16:44:48+00:00
# ニューラルマシン翻訳堅牢性のための文境界増強
# c: 1100 	 2020-10-20 18:19:28+00:00
# インタラクティブ3Dシーンモデリングのための画像主導の家具スタイル
# c: 1200 	 2020-10-19 22:15:03+00:00
# 音声感情認識のためのマルチウィンドウデータ増強アプローチ
# c: 1300 	 2020-10-19 09:07:57+00:00
# 確率的コストによる最適輸送のためのベイジアン推論
# c: 1400 	 2020-10-17 09:54:51+00:00
# 深強化学習における自己監視探査のための変分動的
# c: 1500 	 2020-10-16 06:33:45+00:00
# PRIVNETS：推奨事項の転送学習におけるプライベート属性を保護する
# c: 1600 	 2020-10-15 10:09:09+00:00
# 人工ニューラルネットワークによる反射率プロファイル反転に向けて
# c: 1700 	 2020-10-14 12:08:45+00:00
# InstantEmbedding：効率的なローカルノード表現
# c: 1800 	 2020-10-13 10:10:24+00:00
# 変分自己審理器による動的現象の確率的埋め込み
# c: 1900 	 2020-10-12 11:29:06+00:00
# 必要なものを読み込む：多言語バートのより小さなバージョン
# c: 2000 	 2020-10-10 19:33:53+00:00
# 半監視ニューラルネットワークは、CoviD-19スプレッドをモデリングするための逆問題を解決する
# c: 2100 	 2020-10-09 13:23:01+00:00
# ディープラーニングによる視聴覚音声隠蔽
# c: 2200 	 2020-10-08 15:11:28+00:00
# 深部ニューラルネットワークの予測間隔
# c: 2300 	 2020-10-07 15:04:20+00:00
# WasserStein AutoEncodersを積み重ねることで深い潜在的な階層の学習
# c: 2400 	 2020-10-06 16:13:39+00:00
# BLENDTORCH：リアルタイムの適応ドメインランダム化・ライブラリー
# c: 2500 	 2020-10-05 22:29:51+00:00
# パーソナライズされた連合学習のための下限および最適アルゴリズム
# c: 2600 	 2020-10-05 06:34:23+00:00
# 頂点InfoMax Poolingを持つグラフクロスネットワーク
# c: 2700 	 2020-10-03 13:53:30+00:00
# 非同期確率連続凸近似による実用プリコーディング
# c: 2800 	 2020-10-02 08:01:24+00:00
# 深く不完全なマルチビュー複数のクラスタリング
# query:cat:'cs.LG AND submittedDate:[20201101000000 TO 20201130235959]'
# c: 0 	 2020-11-30 23:53:45+00:00
# 高エネルギー物理学におけるスパースデータ生成のためのグラフ生成敵対的ネットワーク
# c: 100 	 2020-11-30 06:59:20+00:00
# ハーフスペースの堅牢で私的な学習
# c: 200 	 2020-11-27 18:46:34+00:00
# ドメイン知識を使用して自分自身を説明するように機械を教える
# c: 300 	 2020-11-26 08:29:50+00:00
# 説明可能な表現可能なテンソル化された神経常微分方程式
# c: 400 	 2020-11-24 22:26:14+00:00
# 半監視学習技術を用いた衛星画像からの災害後損傷の評価
# c: 500 	 2020-11-23 21:38:57+00:00
# オンラインマッチング、フロー、またはロードバランシングのための学習可能およびインスタンスロバスト予測
# c: 600 	 2020-11-22 17:16:17+00:00
# プログラムのような深い生成モデルを学ぶ：自由なカテゴリ
# c: 700 	 2020-11-20 15:56:44+00:00
# 一段階検出器における分類の改善
# c: 800 	 2020-11-19 06:03:35+00:00
# 異種グラフのためのスケーラブルグラフニューラルネットワーク
# c: 900 	 2020-11-17 19:12:23+00:00
# マルチモーダルアシスタントの画像から自然な質問を生み出す
# c: 1000 	 2020-11-16 18:59:49+00:00
# 複数の劣化シングル画像超解像のための高速および頑強なカスケードモデル
# c: 1100 	 2020-11-15 10:03:12+00:00
# 無限次元ガウス対策とガウス過程との間のWASPERSTEIN距離のエントロピー正則化
# c: 1200 	 2020-11-13 15:10:40+00:00
# サラダ：行動検出のための自己評価学習
# c: 1300 	 2020-11-12 09:52:14+00:00
# 連邦学習における不均衡データ分類のための給電焦点損失
# c: 1400 	 2020-11-11 09:18:58+00:00
# ストレートスルーグラデーションによるエンドツーエンド音声認識の効率的なニューラルアーキテクチャ検索
# c: 1500 	 2020-11-10 10:58:38+00:00
# 類似言語を翻訳する：多言語変圧器における相互了解度の役割
# c: 1600 	 2020-11-09 09:53:37+00:00
# 人口ベースの変分政策最適化のための報酬条件付きニューラル移動プリミティブ
# c: 1700 	 2020-11-06 22:36:00+00:00
# ガウスの混合物の頑健な学習可能性を解決します
# c: 1800 	 2020-11-05 16:21:26+00:00
# 二値化ニューラルネットワークを検証するためのSMTベースのアプローチ
# c: 1900 	 2020-11-04 09:18:16+00:00
# 伝達的および誘導的シナリオにおける遺伝的アルゴリズムと組み合わせた機械学習法を用いた血液様物質のハイパースペクトル分類
# c: 2000 	 2020-11-03 09:52:37+00:00
# 正規化フローを用いたガウスプロセスの変換
# c: 2100 	 2020-11-02 10:27:29+00:00
# 機械学習リー構造と物理学への応用
# query:cat:'cs.LG AND submittedDate:[20201201000000 TO 20201231235959]'
# c: 0 	 2020-12-31 21:40:40+00:00
# グラフ学習のためのボソニックランダムウォークネットワーク
# c: 100 	 2020-12-30 11:00:36+00:00
# 遠近法：雑談（及び、特徴学習、遅延トレーニングの統一の深調学習の相図
# c: 200 	 2020-12-28 14:43:04+00:00
# 座標畳み込みと深部残留ユニットを用いた病変網 - 皮膚病変セグメンテーション
# c: 300 	 2020-12-25 01:39:26+00:00
# 予想による予測：インタラクション学習に基づく行動条件付き予測法
# c: 400 	 2020-12-23 07:39:54+00:00
# 自己説明による学習、ニューラルアーキテクチャ検索への応用
# c: 500 	 2020-12-22 01:35:47+00:00
# ソフトウェア生成ポイントクラウドから平面方向を抽出するための自動システムに向けて
# c: 600 	 2020-12-20 16:08:56+00:00
# イメージングおよび人工知能技術による中枢性漿液性網膜症の検出における最近の発展レビュー
# c: 700 	 2020-12-18 08:49:04+00:00
# 正則化されたニューラルネットワークを用いた柔軟な非パラメトリックモデリング
# c: 800 	 2020-12-17 02:07:37+00:00
# ザモットモデル選択による音声強調
# c: 900 	 2020-12-16 01:50:46+00:00
# DialogXL：マルチパーティ会話感情認識のためのオールインワンXLNET
# c: 1000 	 2020-12-15 03:55:03+00:00
# 一般的な枠組みとしての乗法報酬によるマルコフ決定プロセスにおける正確な解決策
# c: 1100 	 2020-12-14 06:53:13+00:00
# 実世界環境におけるニューラルネットワークの信頼性キットの適用
# c: 1200 	 2020-12-12 04:32:52+00:00
# GANトレーニングを監視するための尺度としての双対ギャップについて
# c: 1300 	 2020-12-10 21:14:18+00:00
# COMPPOOL：階層グラフ表現学習のための解釈可能なグラフプールフレームワーク
# c: 1400 	 2020-12-09 20:59:25+00:00
# Barrettのセグメンテーションのための教師なし敵対的ドメイン適応
# c: 1500 	 2020-12-08 19:37:58+00:00
# 手の届くとドラッグタスクでのさまざまなモードのツール使用モードの出現
# c: 1600 	 2020-12-07 20:30:39+00:00
# 植物成長の多段階予測のための注意メカニズムを有する自己復元ウェーブレットベースの深いニューラルネットワーク
# c: 1700 	 2020-12-07 01:19:08+00:00
# ゲーマーのプライベートネットワークの機械学習予測
# c: 1800 	 2020-12-04 20:40:36+00:00
# ペプチド-MHC結合予測のためのランキングベースの畳み込みニューラルネットワークモデル
# c: 1900 	 2020-12-03 18:34:10+00:00
# DR-Covid：SARS-COV-2薬物再利用のためのグラフニューラルネットワーク
# c: 2000 	 2020-12-02 19:17:19+00:00
# 水文のための物理学的誘導機学習法
# c: 2100 	 2020-12-01 16:58:01+00:00
# 自然言語推論と意味類似性タスクのためのメタ埋め込み
# query:cat:'cs.LG AND submittedDate:[20210101000000 TO 20210131235959]'
# c: 0 	 2021-01-31 23:59:24+00:00
# 非州の武装グループのためのグローバルサポートネットワークの定量化（NAGS）
# c: 100 	 2021-01-29 18:40:17+00:00
# 驚くべきことに単純な半監視ドメイン適応
# c: 200 	 2021-01-28 04:25:51+00:00
# 時系列回帰および予測のためのニューラルネットワークにおける自己相関エラーの調整
# c: 300 	 2021-01-26 19:14:14+00:00
# 平均ローカライズされた近接性：優れたデフォルトの1クラスの分類パフォーマンスを持つ新しいデータ記述子
# c: 400 	 2021-01-25 10:59:00+00:00
# ネットワーク上の機械学習タスクの適応スケジューリング
# c: 500 	 2021-01-22 21:59:44+00:00
# AI / MLシステムにおける脆弱性の管理について
# c: 600 	 2021-01-21 08:22:18+00:00
# 畳み込みニューラルネットワークに対する深極度学習機械の優位性
# c: 700 	 2021-01-19 17:44:50+00:00
# 代数トポロジーを用いた人工ニューラルネットワークの構造特性の決定
# c: 800 	 2021-01-18 08:01:06+00:00
# 分散投影された亜粒子アルゴリズムにおけるインサイダー攻撃の検出
# c: 900 	 2021-01-15 21:59:18+00:00
# 流通敵対研修における基礎的トレードオフ
# c: 1000 	 2021-01-14 09:02:45+00:00
# 共同エージェントの堅牢性を評価する
# c: 1100 	 2021-01-12 22:51:55+00:00
# グラフフィルタリングによる分類精度の向上
# c: 1200 	 2021-01-11 12:32:15+00:00
# 機械学習を用いた投薬安全性の保証のための枠組み
# c: 1300 	 2021-01-08 11:30:50+00:00
# 無限二次元折り返し型深いニューラルネットワーク
# c: 1400 	 2021-01-06 23:54:10+00:00
# 血小板使用法のための需要予測：独自の時系列から多変量モデルへ
# c: 1500 	 2021-01-05 04:51:12+00:00
# 非対応$ \ eLL_P $ボール投影に対する効率的なアプローチに向けて：アルゴリズムと分析
# c: 1600 	 2021-01-02 23:35:27+00:00
# ビニール：視索言語モデルにおける視覚表現の再検討
# query:cat:'cs.LG AND submittedDate:[20210201000000 TO 20210228235959]'
# c: 0 	 2021-02-28 23:00:34+00:00
# アクティブな学習のためのフィードバックコーディング
# c: 100 	 2021-02-27 03:04:21+00:00
# グラフ自己監視学習：調査
# c: 200 	 2021-02-25 20:15:18+00:00
# 局所確率勾配降下昇降率：収束解析とコミュニケーション効率
# c: 300 	 2021-02-24 21:43:16+00:00
# 論理オプションフレームワーク
# c: 400 	 2021-02-23 21:01:06+00:00
# ベビー直感ベンチマーク（BIB）：目標、嗜好、他人の行動を肥やす
# c: 500 	 2021-02-22 18:36:11+00:00
# スケッチベースのモデルでのマルチデスティネーショントリップのモデリング
# c: 600 	 2021-02-21 04:28:49+00:00
# オンライン内のメタラニーを介したニューラルネットワークをスパイキングするための高速オンデバイス適応
# c: 700 	 2021-02-19 11:08:02+00:00
# kbcnmujal @ hasoc-dravidian-codemix-fire2020：憎しみの発話と攻撃的なコード混合ソーシャルメディアテキストの検出のための機械学習の使用
# c: 800 	 2021-02-18 12:03:57+00:00
# 堅牢性保証による順序のニューラルネットワーク合成
# c: 900 	 2021-02-17 07:06:19+00:00
# 分散縮小政策勾配法の収束とサンプル効率について
# c: 1000 	 2021-02-16 11:29:09+00:00
# アース言語によるピックアンドプレースタスクの作成
# c: 1100 	 2021-02-15 15:57:20+00:00
# 補強タスクによる画像品質評価の学習Amenableデータ選択
# c: 1200 	 2021-02-14 04:22:52+00:00
# スパースマルチスケール学習のための前方後方貪欲アプローチ
# c: 1300 	 2021-02-12 15:47:41+00:00
# （検証済み）機械学習に関する計算能力の観点
# c: 1400 	 2021-02-11 17:24:45+00:00
# 考古学データ科学における意味の障壁
# c: 1500 	 2021-02-10 15:40:27+00:00
# WSIのCNN分析による結腸直腸ポリープの異形成
# c: 1600 	 2021-02-09 18:04:37+00:00
# スムージングRELUアクティベーションを持つディープネットワークを使用して、ロジスティック損失を補間する勾配降下が発生しますか？
# c: 1700 	 2021-02-08 17:27:34+00:00
# 訓練されたRELUニューラルネットワークの混合整数最適化のための分割ベースの定式化
# c: 1800 	 2021-02-07 14:19:07+00:00
# 可能性マッチングによるオンライン制限記憶ニューラルリニアバンディット
# c: 1900 	 2021-02-05 16:26:17+00:00
# 因果発見のサンプルの複雑さとドメイン専門知識の価値
# c: 2000 	 2021-02-04 14:01:05+00:00
# キルヒホフプレートの曲げ分析のための深いコロケーション法
# c: 2100 	 2021-02-03 04:11:39+00:00
# 監督学習における公平性に及ぼすデータ処理の影響
# c: 2200 	 2021-02-02 04:44:45+00:00
# 中央部分割による人機械共同ビデオ符号化
# query:cat:'cs.LG AND submittedDate:[20210301000000 TO 20210331235959]'
# c: 0 	 2021-03-31 23:58:34+00:00
# ハイブリッドガイド付き変分オートエンコーダを用いたイベントデータに関するジェスチャ類似性解析
# c: 100 	 2021-03-30 19:56:02+00:00
# 離散時間パラメータ推定のための新しいアルゴリズム
# c: 200 	 2021-03-29 20:21:55+00:00
# リカレントニューラルネットワークを用いた信号時間論理仕様からのモデルベースの安全政策検索
# c: 300 	 2021-03-27 21:02:31+00:00
# 熱流束法結果に対する人工ニューラルネットワークの応用に基づく熱透過率予測
# c: 400 	 2021-03-26 02:42:38+00:00
# エーカー：共通化を超えた抽象的な原因推論
# c: 500 	 2021-03-24 22:33:11+00:00
# ベイジアン回帰ゲームへの変分不等式アプローチ
# c: 600 	 2021-03-23 15:24:50+00:00
# 遺伝子カラム生成：高次元多周辺最適輸送問題の高速計算
# c: 700 	 2021-03-22 14:06:21+00:00
# スマートグリッドのための連合学習フレームワーク：共同学習における電力痕跡を確保する
# c: 800 	 2021-03-20 18:37:06+00:00
# 航空遅延予測のための時空間データマイニング
# c: 900 	 2021-03-18 17:58:02+00:00
# 深部ネットワークにおける低ランクシチュニックバイアス
# c: 1000 	 2021-03-17 08:27:01+00:00
# FBCNET：ブレインコンピュータインタフェース用のマルチビュー畳込みニューラルネットワーク
# c: 1100 	 2021-03-15 15:38:47+00:00
# メタラーニングのタスク間でデータを配布する方法
# c: 1200 	 2021-03-13 02:03:53+00:00
# 敵対的な例を中毒にするための学習防衛トランス
# c: 1300 	 2021-03-11 15:21:08+00:00
# 解釈可能な車両状態予測のためのハイブリッド物理学と深部学習モデル
# c: 1400 	 2021-03-10 12:37:18+00:00
# 車線保持性能に基づく気晴らし検知を駆動するための自動機械学習（AutoL）方法
# c: 1500 	 2021-03-09 03:27:33+00:00
# ベースモデルの下での動的価格と学習
# c: 1600 	 2021-03-07 19:46:07+00:00
# Insta-RS：堅牢性と正確さの向上のためのインスタンス単位の無作為化スムージング
# c: 1700 	 2021-03-05 17:09:46+00:00
# Malbert：サイバーセキュリティと悪意のあるソフトウェア検知のための変圧器を使う
# c: 1800 	 2021-03-04 15:34:43+00:00
# 自己監視幾何学的知覚
# c: 1900 	 2021-03-03 11:06:12+00:00
# ワイドグラフニューラルネットワーク：集約的には指数関数的に訓練不能損失につながる
# c: 2000 	 2021-03-02 10:12:26+00:00
# 解釈可能なマルチモーダル嫌い音声検出
# c: 2100 	 2021-03-01 15:53:34+00:00
# 高次元変分推論における課題と機会
# query:cat:'cs.LG AND submittedDate:[20210401000000 TO 20210430235959]'
# c: 0 	 2021-04-30 22:34:32+00:00
# ipatch：リモート敵対パッチ
# c: 100 	 2021-04-29 14:54:11+00:00
# ドメインランダム化の下での学習のためのディープRLエージェントの事前研修
# c: 200 	 2021-04-28 08:50:08+00:00
# PYTORCH表形式：表形式データを用いた深い学習のためのフレームワーク
# c: 300 	 2021-04-26 19:22:27+00:00
# データサブセット選択における制約とサブモニズムのバランスをとる
# c: 400 	 2021-04-24 20:50:41+00:00
# 説明可能な人工知能は、乳がんの患者のより良い予後と関連した腫瘍微小環境条件への新規の洞察を明らかにする
# c: 500 	 2021-04-22 15:10:26+00:00
# 暗黙的にモジュール化されたオーディオビジュアル表現によるポーズ制御可能な話顔の生成
# c: 600 	 2021-04-21 08:42:54+00:00
# 正規化フローを用いたシナリオ生成の主成分密度推定
# c: 700 	 2021-04-19 21:58:52+00:00
# 敵対的代理損失の校正と一貫性
# c: 800 	 2021-04-18 16:32:29+00:00
# 正方形の合計プログラミングによるロボットアームのための証明的な安全な耐性推定
# c: 900 	 2021-04-16 15:26:23+00:00
# ベイジアン最適化における過剰充填：経験的研究と早期停止解
# c: 1000 	 2021-04-15 15:19:21+00:00
# クイックロック：モバイルデバイスによる高速屋内ローカライズのための適応的な深い学習
# c: 1100 	 2021-04-14 09:25:38+00:00
# 数学単語の問題を解決するための弱い監視モデル
# c: 1200 	 2021-04-13 07:51:07+00:00
# 失読症診断のための時間的固有PAC
# c: 1300 	 2021-04-12 02:15:55+00:00
# 大規模な深部学習推薦モデルの高性能、分散トレーニング
# c: 1400 	 2021-04-09 15:55:01+00:00
# 控えめな最小島への悪循環堅牢な一般化
# c: 1500 	 2021-04-08 07:01:42+00:00
# 眼底画像におけるカップとディスクセグメンテーションのための双方向CONVLSTMを持つM-NET
# c: 1600 	 2021-04-07 02:34:03+00:00
# 変分ベイズ用準ニュートン準モンテカルロ
# c: 1700 	 2021-04-05 22:43:14+00:00
# AMP：様式化された物理学ベースの文字管理のための敵対的な運動専用
# c: 1800 	 2021-04-03 23:44:04+00:00
# 離散時間確率過程に対するSTLロバストネスリスク
# c: 1900 	 2021-04-01 21:44:07+00:00
# 制約付き環境で把握する衝突対応ターゲット駆動型オブジェクト
# query:cat:'cs.LG AND submittedDate:[20210501000000 TO 20210531235959]'
# c: 0 	 2021-05-06 17:58:43+00:00
# 3D形状およびSVBRDF取得のための深い偏光イメージング
# c: 100 	 2021-05-05 05:14:08+00:00
# DNNSのサンプル複雑さを推定するための理論的実証的アプローチ
# c: 200 	 2021-05-03 18:53:58+00:00
# 自転車共有システムにおける状況認識需要予測：空間的、気象学的および暦の文脈を組み込む
# c: 300 	 2021-05-01 15:47:42+00:00
# ニューラルネットワークの推論へのPEEK：構造的視覚概念との解釈

# %%
get_by_submitted_date("20210401", "202104302359", category="cs.LG")
# Out:
# query:cat:'cs.LG AND submittedDate:[20210401 TO 202104302359]'
# c: 0 	 2021-04-30 17:53:07+00:00
# NLPモデルの説明ベースの人間のデバッグ：調査
# c: 100 	 2021-04-29 09:59:46+00:00
# Tabaug：エンハンスドテーブル構造認識のためのデータ駆動拡張増強
# c: 200 	 2021-04-27 20:43:25+00:00
# 数学的推論における一般的な知性の役割
# c: 300 	 2021-04-26 15:18:00+00:00
# 回帰アルゴリズムと深部学習との接続の調査
# c: 400 	 2021-04-24 00:33:45+00:00
# グラフニューラルネットワークを用いたスマートグリッドにおけるステルス誤ったデータ注入攻撃の共同検出とローカライズ
# c: 500 	 2021-04-22 08:24:15+00:00
# ヨーロッパの10 M解像度での大陸規模の土地被覆マッピング（ELC10）
# c: 600 	 2021-04-20 20:03:54+00:00
# マルチクラスのImbalancedデータストリームからの概念ドリフト検出
# c: 700 	 2021-04-19 16:17:12+00:00
# プロキシ分布を用いた敵対的堅牢性の改善
# c: 800 	 2021-04-18 04:30:01+00:00
# 非直接凹面最適化のための複雑さ下限
# c: 900 	 2021-04-16 09:17:00+00:00
# 分子回帰アルゴリズムを用いた確率論的水需要予測
# c: 1000 	 2021-04-15 08:11:47+00:00
# 帰属ネットワーククラスタリングのための変分共埋め学習
# c: 1100 	 2021-04-13 23:21:01+00:00
# 低ランクマニホールド正則化を用いた弱い監視された回帰問題の解決
# c: 1200 	 2021-04-12 20:19:24+00:00
# オープンドメインストーリー生成を評価するためのプロットガイド付き副従事の構築
# c: 1300 	 2021-04-11 03:25:25+00:00
# グラフ最適化による自動加重マルチビュー機能選択
# c: 1400 	 2021-04-09 03:30:27+00:00
# X2CTフロー：フローベースの生成モデルを用いたユニオンまたは複合胸部X線画像からの異なる可能性を有する複数の体積胸部計算断層撮影画像の再構成
# c: 1500 	 2021-04-07 17:58:39+00:00
# ドメインアガベーベルの非標識画像を介したストリーミング自己トレーニング
# c: 1600 	 2021-04-06 16:34:46+00:00
# モデルデータ駆動型構成応答：マルチスケール計算フレームワークへの応用
# c: 1700 	 2021-04-05 14:10:26+00:00
# 安全な確率的凸最適化の最適クエリ複雑さ
# c: 1800 	 2021-04-02 23:10:57+00:00
# Pate-aae：音声コマンドの分類のための教師集団のプライベート集約に敵対的な自己契約者を組み込んだ
# c: 1900 	 2021-04-01 16:37:01+00:00
# 実世界の深部学習申請におけるモデル選択の異なる影響

# %%
def get_year_by_4q(year, category = "cs.AI", base_path = "/hdd/takada/arXivs/"):
    q1_start = year + "0101"
    q1_end   = year + "03312359"
    q2_start = year + "0401"
    q2_end   = year + "06302359"
    q3_start = year + "0701"
    q3_end   = year + "09302359"
    q4_start = year + "1001"
    q4_end   = year + "12312359"

    get_by_submitted_date(q1_start, q1_end, category=category, base_path=base_path)
    get_by_submitted_date(q2_start, q2_end, category=category, base_path=base_path)
    get_by_submitted_date(q3_start, q3_end, category=category, base_path=base_path)
    get_by_submitted_date(q4_start, q4_end, category=category, base_path=base_path)

# %%
def get_10year_by_category(category = "cs.AI"):
    base_path = "/hdd/takada/arXivs/arXiv_" + category + "/"
    os.makedirs(base_path, exist_ok=True)
    for year in range(2012,2021):
        get_year_by_4q(year=str(year), category=category, base_path=base_path)

    get_by_submitted_date("20210101", "202103312359", category=category)
    get_by_submitted_date("20210401", "202104302359", category=category)

# %%
get_10year_by_category(category="cs.LG")  #Learning
# Out:
# query:cat:'cs.LG AND submittedDate:[20120101 TO 201203312359]'
# c: 0 	 2012-03-31 21:15:28+00:00
# オンライン行列予測のための最適アルゴリズム
# c: 100 	 2012-02-25 20:23:37+00:00
# 単語観測に関するトレーニング制限Boltzmannマシン
# c: 200 	 2012-01-11 21:03:55+00:00
# 回帰のための確率的な低ランクカーネル学習
# query:cat:'cs.LG AND submittedDate:[20120401 TO 201206302359]'
# c: 0 	 2012-06-30 23:07:03+00:00
# マルチラベル分類と部分フィードバックによるランキングについて
# c: 100 	 2012-06-27 19:59:59+00:00
# わずかな正確なスパース線形分類のための類似性学習
# c: 200 	 2012-06-18 15:36:16+00:00
# ランクネットによる比較ベースの学習
# c: 300 	 2012-06-13 15:33:32+00:00
# 任意の分布による線形非環式モデルの因果的発見
# c: 400 	 2012-05-09 17:24:52+00:00
# ベイジアンオンライン分類のための仮想ベクトルマシン
# c: 500 	 2012-04-05 15:34:30+00:00
# 暗黙のフィードバックからの状況対応推奨のための高速ALSベースのテンソル因数分解
# query:cat:'cs.LG AND submittedDate:[20120701 TO 201209302359]'
# c: 0 	 2012-09-29 04:58:22+00:00
# 楽観的なエージェントは漸近的に最適です
# c: 100 	 2012-08-14 17:04:19+00:00
# 社会的勧告のためのプログラム合成を使用する
# c: 200 	 2012-07-11 14:54:55+00:00
# 専門家の確率を集約するための生成ベイジアンモデル
# query:cat:'cs.LG AND submittedDate:[20121001 TO 201212312359]'
# c: 0 	 2012-12-31 21:07:21+00:00
# Betheは境界とグローバル最適値を近似しています
# c: 100 	 2012-12-03 13:00:27+00:00
# 動的推奨システム：予測の精度を向上させるためのクラスタベースのバイアスの使用
# c: 200 	 2012-11-03 00:41:46+00:00
# パーティションツリーの重み付け
# c: 300 	 2012-10-16 17:45:11+00:00
# スペクトルクラスタリングにおける丸めへのモデルベースのアプローチ
# query:cat:'cs.LG AND submittedDate:[20130101 TO 201303312359]'
# c: 0 	 2013-03-31 06:45:47+00:00
# 並列計算はESSです
# c: 100 	 2013-02-28 18:56:56+00:00
# 不確実性のためのオンライン学習を伴うGMMプラリの下でのMMSE推定を用いた正則化NMFを用いたソース分離
# c: 200 	 2013-02-03 22:12:52+00:00
# 局所精度推定を用いた加重過半数投票を用いた分類器アンサンブルのためのゲーム - 理論的フレームワーク
# c: 300 	 2013-01-16 15:50:34+00:00
# 過去からのカップリングを用いた信念ネットワークの推論
# c: 400 	 2013-01-04 18:55:41+00:00
# 階層ベイズの借入強度：ディリシェクトベース測定の後濃度
# query:cat:'cs.LG AND submittedDate:[20130401 TO 201306302359]'
# c: 0 	 2013-06-29 16:36:30+00:00
# 離散ベイズシーケンス予測器に対する濃度と信頼
# c: 100 	 2013-06-03 19:13:53+00:00
# いくつかのポリシー検索動的プログラミングアルゴリズムのパフォーマンス限界について
# c: 200 	 2013-04-29 07:17:31+00:00
# すべての間隔で最適な償却後悔
# query:cat:'cs.LG AND submittedDate:[20130701 TO 201309302359]'
# c: 0 	 2013-09-30 12:48:35+00:00
# 戦略的データソースからの線形回帰
# c: 100 	 2013-09-05 23:21:02+00:00
# 暗黙の事前調整とサンプリングによる深さニューラルネットワークのヘッシアンフリー最適化の加速
# c: 200 	 2013-07-29 01:15:25+00:00
# データマイニング方法を用いた選挙を予想する参加
# c: 300 	 2013-07-01 01:09:25+00:00
# 探索的学習
# query:cat:'cs.LG AND submittedDate:[20131001 TO 201312312359]'
# c: 0 	 2013-12-31 18:17:09+00:00
# 非常に疎圧縮されたカウントを持つまばらな回復
# c: 100 	 2013-12-20 00:21:36+00:00
# 深いスパースコーディングによる教師なし機能学習
# c: 200 	 2013-11-29 18:53:32+00:00
# バイナリハッシングにおける非対称性の力
# c: 300 	 2013-11-07 11:33:14+00:00
# 最大エントロピー緩和経路
# c: 400 	 2013-10-09 12:18:29+00:00
# M-Power正規二乗退避
# query:cat:'cs.LG AND submittedDate:[20140101 TO 201403312359]'
# c: 0 	 2014-03-31 19:43:53+00:00
# ランダム投影のための符号化および近隣検索の近似
# c: 100 	 2014-03-02 04:18:00+00:00
# 異常検出のためのネットワークトラフィック分解
# c: 200 	 2014-02-10 05:45:29+00:00
# 過剰損失との二次範囲
# c: 300 	 2014-01-16 16:33:23+00:00
# 深海モデルにおける確率的逆散布とおおよその推論
# query:cat:'cs.LG AND submittedDate:[20140401 TO 201406302359]'
# c: 0 	 2014-06-30 22:00:57+00:00
# 最近傍分類のための収束率
# c: 100 	 2014-06-15 02:39:37+00:00
# 電力需要の間隔予測：新しい二変量EMDベースの支持ベクトル回帰モデリングフレームワーク
# c: 200 	 2014-05-26 23:11:40+00:00
# 近位補強学習：Primal  - 二重スペースにおける逐次意思決定の新しい理論
# c: 300 	 2014-04-30 21:48:34+00:00
# インクリメンタル反復正則化を伴う学習
# c: 400 	 2014-04-04 03:02:44+00:00
# マルチエージェントPOMDPSのためのスケーラブルな計画と学習：拡張版
# query:cat:'cs.LG AND submittedDate:[20140701 TO 201409302359]'
# c: 0 	 2014-09-30 15:49:59+00:00
# 分散検出：有限時間分析とネットワークトポロジーの影響
# c: 100 	 2014-09-08 23:47:51+00:00
# 対称的な非負の定義スマーホーマーを使用した疎加法モデル
# c: 200 	 2014-08-11 06:52:46+00:00
# 序数回帰法の一貫性について
# c: 300 	 2014-07-22 23:18:08+00:00
# U湾曲最適化問題：元のアルゴリズムの改善と時間の複雑さ解析
# query:cat:'cs.LG AND submittedDate:[20141001 TO 201412312359]'
# c: 0 	 2014-12-31 19:36:55+00:00
# accams：マトリックスを簡潔にする
# c: 100 	 2014-12-20 04:11:33+00:00
# ブートストラップを使用したノイズの多いラベルに関する深いニューラルネットワークのトレーニング
# c: 200 	 2014-12-08 02:23:40+00:00
# MLITB：ブラウザでの機械学習
# c: 300 	 2014-11-18 05:53:06+00:00
# クロスモーダル類似性学習低ランク双線形配合
# c: 400 	 2014-10-31 09:01:27+00:00
# パーティションワイズリニアモデル
# c: 500 	 2014-10-14 07:41:34+00:00
# デシメーションアルゴリズムによる不正行為の検出
# query:cat:'cs.LG AND submittedDate:[20150101 TO 201503312359]'
# c: 0 	 2015-03-31 23:27:03+00:00
# 適応的に選択された比較を介したクラウドソーシング特徴発見
# c: 100 	 2015-03-12 12:59:25+00:00
# マイクロトピックのグリッドの階層的学習
# c: 200 	 2015-02-27 17:22:53+00:00
# 誤り訂正因子
# c: 300 	 2015-02-12 12:32:39+00:00
# 注文に敏感で意味対応のトピックモデリング
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-e7a2f243d695> in <module>
# ----> 1 get_10year_by_category(category="cs.LG")  #Learning
#
# <ipython-input-8-879b0359cf00> in get_10year_by_category(category)
#       3     os.makedirs(base_path, exist_ok=True)
#       4     for year in range(2012,2021):
# ----> 5         get_year_by_4q(year=str(year), category=category, base_path=base_path)
#       6
#       7     get_by_submitted_date("20210101", "202103312359", category=category)
#
# <ipython-input-4-574c912054a6> in get_year_by_4q(year, category, base_path)
#       9     q4_end   = year + "12312359"
#      10
# ---> 11     get_by_submitted_date(q1_start, q1_end, category=category, base_path=base_path)
#      12     get_by_submitted_date(q2_start, q2_end, category=category, base_path=base_path)
#      13     get_by_submitted_date(q3_start, q3_end, category=category, base_path=base_path)
#
# <ipython-input-3-7e4c92adb220> in get_by_submitted_date(start_date, end_date, category, base_path)
#      44                 print(title_jp)
#      45             c += 1
# ---> 46             sleep(2)
#
# KeyboardInterrupt:

# %%
# https://arxiv.org/help/api/user-manual#subject_classifications

get_10year_by_category(category="eess.AS") #音声＆音声処理
get_10year_by_category(category="cs.IR")   #情報検索
get_10year_by_category(category="cs.IT")   #情報理論
get_10year_by_category(category="cs.NE")   #ニューラルおよび進化的計算
get_10year_by_category(category="cs.AI")   #人工知能
# Out:
# query:cat:'eess.AS AND submittedDate:[20100101 TO 201003312359]'
# 20100101 arxiv read done. (0)
# query:cat:'eess.AS AND submittedDate:[20100401 TO 201006302359]'
# 20100401 arxiv read done. (0)
# query:cat:'eess.AS AND submittedDate:[20100701 TO 201009302359]'
# 20100701 arxiv read done. (0)
# query:cat:'eess.AS AND submittedDate:[20101001 TO 201012312359]'
# 20101001 arxiv read done. (0)
# query:cat:'eess.AS AND submittedDate:[20110101 TO 201103312359]'
# 20110101 arxiv read done. (0)
# query:cat:'eess.AS AND submittedDate:[20110401 TO 201106302359]'
# 20110401 arxiv read done. (0)
# query:cat:'eess.AS AND submittedDate:[20110701 TO 201109302359]'
# 20110701 arxiv read done. (0)
# query:cat:'eess.AS AND submittedDate:[20111001 TO 201112312359]'
# 20111001 arxiv read done. (2)
# c: 0 	 2011-10-06T10:21:04Z
# query:cat:'eess.AS AND submittedDate:[20120101 TO 201203312359]'
# 20120101 arxiv read done. (0)
# query:cat:'eess.AS AND submittedDate:[20120401 TO 201206302359]'
# 20120401 arxiv read done. (0)
# query:cat:'eess.AS AND submittedDate:[20120701 TO 201209302359]'
# 20120701 arxiv read done. (1)
# c: 0 	 2012-08-07T13:33:40Z
# query:cat:'eess.AS AND submittedDate:[20121001 TO 201212312359]'
# 20121001 arxiv read done. (0)
# query:cat:'eess.AS AND submittedDate:[20130101 TO 201303312359]'
# 20130101 arxiv read done. (1)
# c: 0 	 2013-01-16T07:23:19Z
# query:cat:'eess.AS AND submittedDate:[20130401 TO 201306302359]'
# 20130401 arxiv read done. (0)
# query:cat:'eess.AS AND submittedDate:[20130701 TO 201309302359]'
# 20130701 arxiv read done. (0)
# query:cat:'eess.AS AND submittedDate:[20131001 TO 201312312359]'
# 20131001 arxiv read done. (0)
# query:cat:'eess.AS AND submittedDate:[20140101 TO 201403312359]'
# 20140101 arxiv read done. (0)
# query:cat:'eess.AS AND submittedDate:[20140401 TO 201406302359]'
# 20140401 arxiv read done. (0)
# query:cat:'eess.AS AND submittedDate:[20140701 TO 201409302359]'
# 20140701 arxiv read done. (0)
# query:cat:'eess.AS AND submittedDate:[20141001 TO 201412312359]'
# 20141001 arxiv read done. (0)
# query:cat:'eess.AS AND submittedDate:[20150101 TO 201503312359]'
# 20150101 arxiv read done.
ND submittedDate:[20200101 TO 202003312359]'
# 20200101 arxiv read done. (501)
# c: 0 	 2020-01-01T10:14:54Z
# c: 100 	 2020-01-22T11:34:17Z
# c: 200 	 2020-02-08T02:47:53Z
# c: 300 	 2020-02-24T13:50:57Z
# c: 400 	 2020-03-12T20:47:36Z
# c: 500 	 2020-03-31T21:00:54Z
# query:cat:'cs.NI AND submittedDate:[20200401 TO 202006302359]'
# 20200401 arxiv read done. (550)
# c: 0 	 2020-04-01T06:02:09Z
# c: 100 	 2020-04-16T13:28:20Z
# c: 200 	 2020-05-01T07:23:59Z
# c: 300 	 2020-05-17T10:25:51Z
# c: 400 	 2020-06-02T17:52:32Z
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-a882c63696ba> in <module>
#       7 get_10year_by_category(category="cs.AI")   #人工知能
#       8
# ----> 9 get_10year_by_category(category="cs.NI")   #ネットワークとインターネットアーキテクチャ
#      10 get_10year_by_category(category="cs.SE")   #ソフトウェア工学
#      11 get_10year_by_category(category="cs.PL")   #プログラミング言語
#
# <ipython-input-4-7ea8de6b06c5> in get_10year_by_category(category)
#       3     os.makedirs(base_path, exist_ok=True)
#       4     for year in range(2010,2021):
# ----> 5         get_year_by_4q(year=str(year), category=category, base_path=base_path)
#       6
#       7     get_by_submitted_date("20210101", "202103312359")
#
# <ipython-input-3-abf13e07078f> in get_year_by_4q(year, category, base_path)
#      10
#      11     get_by_submitted_date(q1_start, q1_end, category=category, base_path=base_path)
# ---> 12     get_by_submitted_date(q2_start, q2_end, category=category, base_path=base_path)
#      13     get_by_submitted_date(q3_start, q3_end, category=category, base_path=base_path)
#      14     get_by_submitted_date(q4_start, q4_end, category=category, base_path=base_path)
#
# <ipython-input-2-2e2ec9cd5e7c> in get_by_submitted_date(start_date, end_date, category, base_path)
#      24             abst = abst.replace("\n","")
#      25
# ---> 26             title_jp =  str(translator.translate(title, src='en' ,dest='ja').text)
#      27             abst_jp =  str(translator.translate(abst, src='en' ,dest='ja').text)
#      28
#
# ~/.local/lib/python3.6/site-packages/googletrans/client.py in translate(self, text, dest, src)
#     217
#     218         data = json.loads(resp)
# --> 219         parsed = json.loads(data[0][2])
#     220         # not sure
#     221         should_spacing = parsed[1][0][0][3]
#
# /usr/lib64/python3.6/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346         if not isinstance(s, (bytes, bytearray)):
#     347             raise TypeError('the JSON object must be str, bytes or bytearray, '
# --> 348                             'not {!r}'.format(s.__class__.__name__))
#     349         s = s.decode(detect_encoding(s), 'surrogatepass')
#     350
#
# TypeError: the JSON object must be str, bytes or bytearray, not 'NoneType'

# %%
get_10year_by_category(category="cs.CL")   #Computation and Language
get_10year_by_category(category="cs.NI")   #ネットワークとインターネットアーキテクチャ
get_10year_by_category(category="cs.SE")   #ソフトウェア工学
get_10year_by_category(category="cs.PL")   #プログラミング言語
get_10year_by_category(category="cs.GT")   #コンピュータサイエンスとゲーム理論
# Out:
# query:cat:'cs.CL AND submittedDate:[20100101 TO 201003312359]'
# 20100101 arxiv read done. (31)
# c: 0 	 2010-01-13T18:51:08Z
# query:cat:'cs.CL AND submittedDate:[20100401 TO 201006302359]'
# 20100401 arxiv read done. (19)
# c: 0 	 2010-04-19T13:11:56Z
# query:cat:'cs.CL AND submittedDate:[20100701 TO 201009302359]'
# 20100701 arxiv read done. (17)
# c: 0 	 2010-07-06T16:09:43Z
# query:cat:'cs.CL AND submittedDate:[20101001 TO 201012312359]'
# 20101001 arxiv read done.
ND submittedDate:[20131001 TO 201312312359]'
# 20131001 arxiv read done. (216)
# c: 0 	 2013-10-01T15:33:30Z
# c: 100 	 2013-11-13T10:26:58Z
# c: 200 	 2013-12-21T00:56:56Z
# query:cat:'cs.DC AND submittedDate:[20140101 TO 201403312359]'
# 20140101 arxiv read done. (178)
# c: 0 	 2014-01-02T01:42:23Z
# c: 100 	 2014-02-22T16:29:22Z
# query:cat:'cs.DC AND submittedDate:[20140401 TO 201406302359]'
# 20140401 arxiv read done. (174)
# c: 0 	 2014-04-01T00:37:24Z
# c: 100 	 2014-05-12T16:51:53Z
# query:cat:'cs.DC AND submittedDate:[20140701 TO 201409302359]'
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# <ipython-input-7-0459896f8b81> in <module>
#       4 get_10year_by_category(category="cs.PL")   #プログラミング言語
#       5 get_10year_by_category(category="cs.GT")   #コンピュータサイエンスとゲーム理論
# ----> 6 get_10year_by_category(category="cs.DC")   #分散、並列、およびクラスターコンピューティング
#
# <ipython-input-4-7ea8de6b06c5> in get_10year_by_category(category)
#       3     os.makedirs(base_path, exist_ok=True)
#       4     for year in range(2010,2021):
# ----> 5         get_year_by_4q(year=str(year), category=category, base_path=base_path)
#       6
#       7     get_by_submitted_date("20210101", "202103312359")
#
# <ipython-input-3-abf13e07078f> in get_year_by_4q(year, category, base_path)
#      11     get_by_submitted_date(q1_start, q1_end, category=category, base_path=base_path)
#      12     get_by_submitted_date(q2_start, q2_end, category=category, base_path=base_path)
# ---> 13     get_by_submitted_date(q3_start, q3_end, category=category, base_path=base_path)
#      14     get_by_submitted_date(q4_start, q4_end, category=category, base_path=base_path)
#
# <ipython-input-2-2e2ec9cd5e7c> in get_by_submitted_date(start_date, end_date, category, base_path)
#       6     print("query:"+ query)
#       7
# ----> 8     result_list = arxiv.query(query = query, sort_by='submittedDate', sort_order='ascending')
#       9     num = len(result_list)
#      10     print(start_date + " arxiv read done. (" + str(num) + ")" )
#
# ~/.local/lib/python3.6/site-packages/arxiv/arxiv.py in query(query, id_list, prune, max_results, start, sort_by, sort_order, max_chunk_results, iterative)
#     223         max_chunk_results=max_chunk_results)
#     224
# --> 225     return search.download(iterative=iterative)
#     226
#     227
#
# ~/.local/lib/python3.6/site-packages/arxiv/arxiv.py in download(self, iterative)
#     201         else:
#     202             results = list()
# --> 203             for result in self._get_next():
#     204                 # Only append result if title is not empty
#     205                 results = results + result
#
# ~/.local/lib/python3.6/site-packages/arxiv/arxiv.py in _get_next(self)
#     157                 max_results=min(n_left, self.max_chunk_results))
#     158
# --> 159             results = self._parse(url)
#     160
#     161             # Update the entries left to download
#
# ~/.local/lib/python3.6/site-packages/arxiv/arxiv.py in _parse(self, url)
#      89         Downloads the data provided by the REST endpoint given in the url.
#      90         """
# ---> 91         result = feedparser.parse(url)
#      92
#      93         if result.get('status') != 200:
#
# ~/.local/lib/python3.6/site-packages/feedparser/api.py in parse(url_file_stream_or_string, etag, modified, agent, referrer, handlers, request_headers, response_headers, resolve_relative_uris, sanitize_html)
#     212     )
#     213
# --> 214     data = _open_resource(url_file_stream_or_string, etag, modified, agent, referrer, handlers, request_headers, result)
#     215
#     216     if not data:
#
# ~/.local/lib/python3.6/site-packages/feedparser/api.py in _open_resource(url_file_stream_or_string, etag, modified, agent, referrer, handlers, request_headers, result)
#     112     if isinstance(url_file_stream_or_string, str) \
#     113        and urllib.parse.urlparse(url_file_stream_or_string)[0] in ('http', 'https', 'ftp', 'file', 'feed'):
# --> 114         return http.get(url_file_stream_or_string, etag, modified, agent, referrer, handlers, request_headers, result)
#     115
#     116     # try to open with native open function (if url_file_stream_or_string is a filename)
#
# ~/.local/lib/python3.6/site-packages/feedparser/http.py in get(url, etag, modified, agent, referrer, handlers, request_headers, result)
#     156     opener = urllib.request.build_opener(*tuple(handlers + [_FeedURLHandler()]))
#     157     opener.addheaders = []  # RMK - must clear so we only send our custom User-Agent
# --> 158     f = opener.open(request)
#     159     data = f.read()
#     160     f.close()
#
# /usr/lib64/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     524             req = meth(req)
#     525
# --> 526         response = self._open(req, data)
#     527
#     528         # post-process response
#
# /usr/lib64/python3.6/urllib/request.py in _open(self, req, data)
#     542         protocol = req.type
#     543         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 544                                   '_open', req)
#     545         if result:
#     546             return result
#
# /usr/lib64/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# /usr/lib64/python3.6/urllib/request.py in http_open(self, req)
#    1375
#    1376     def http_open(self, req):
# -> 1377         return self.do_open(http.client.HTTPConnection, req)
#    1378
#    1379     http_request = AbstractHTTPHandler.do_request_
#
# /usr/lib64/python3.6/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1350             except OSError as err: # timeout error
#    1351                 raise URLError(err)
# -> 1352             r = h.getresponse()
#    1353         except:
#    1354             h.close()
#
# /usr/lib64/python3.6/http/client.py in getresponse(self)
#    1344         try:
#    1345             try:
# -> 1346                 response.begin()
#    1347             except ConnectionError:
#    1348                 self.close()
#
# /usr/lib64/python3.6/http/client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# /usr/lib64/python3.6/http/client.py in _read_status(self)
#     274             # Presumably, the server closed the connection before
#     275             # sending a valid response.
# --> 276             raise RemoteDisconnected("Remote end closed connection without"
#     277                                      " response")
#     278         try:
#
# RemoteDisconnected: Remote end closed connection without response

# %%
get_10year_by_category(category="cs.LG")  #Learning
get_10year_by_category(category="cs.DC")  #分散、並列、およびクラスターコンピューティング
# Out:
# query:cat:'cs.LG AND submittedDate:[20100101 TO 201003312359]'
# 20100101 arxiv read done. (84)
# c: 0 	 2010-01-03T19:54:40Z
# query:cat:'cs.LG AND submittedDate:[20100401 TO 201006302359]'
# 20100401 arxiv read done. (94)
# c: 0 	 2010-04-02T19:26:47Z
# query:cat:'cs.LG AND submittedDate:[20100701 TO 201009302359]'
# 20100701 arxiv read done. (81)
# c: 0 	 2010-07-01T17:40:01Z
# query:cat:'cs.LG AND submittedDate:[20101001 TO 201012312359]'
# 20101001 arxiv read done. (75)
# c: 0 	 2010-10-01T03:23:17Z
# query:cat:'cs.LG AND submittedDate:[20110101 TO 201103312359]'
# 20110101 arxiv read done. (83)
# c: 0 	 2011-01-02T20:20:27Z
# query:cat:'cs.LG AND submittedDate:[20110401 TO 201106302359]'
# 20110401 arxiv read done. (117)
# c: 0 	 2011-04-01T08:48:54Z
# c: 100 	 2011-06-19T04:20:16Z
# query:cat:'cs.LG AND submittedDate:[20110701 TO 201109302359]'
# 20110701 arxiv read done. (125)
# c: 0 	 2011-07-03T07:33:51Z
# c: 100 	 2011-09-12T07:45:03Z
# query:cat:'cs.LG AND submittedDate:[20111001 TO 201112312359]'
# 20111001 arxiv read done. (144)
# c: 0 	 2011-10-01T01:07:03Z
# c: 100 	 2011-12-06T00:13:44Z
# query:cat:'cs.LG AND submittedDate:[20120101 TO 201203312359]'
# 20120101 arxiv read done. (214)
# c: 0 	 2012-01-01T09:05:33Z
# c: 100 	 2012-02-16T16:40:56Z
# c: 200 	 2012-03-20T21:32:33Z
# query:cat:'cs.LG AND submittedDate:[20120401 TO 201206302359]'
# 20120401 arxiv read done. (507)
# c: 0 	 2012-04-01T07:07:27Z
# c: 100 	 2012-05-09T17:14:10Z
# c: 200 	 2012-06-13T15:09:50Z
# c: 300 	 2012-06-18T15:33:25Z
# c: 400 	 2012-06-27T19:59:59Z
# c: 500 	 2012-06-27T19:59:59Z
# query:cat:'cs.LG AND submittedDate:[20120701 TO 201209302359]'
# 20120701 arxiv read done. (250)
# c: 0 	 2012-07-02T02:57:30Z
# c: 100 	 2012-07-22T21:01:09Z
# c: 200 	 2012-09-11T18:16:56Z
# query:cat:'cs.LG AND submittedDate:[20121001 TO 201212312359]'
# 20121001 arxiv read done. (366)
# c: 0 	 2012-10-01T17:08:25Z
# c: 100 	 2012-10-19T15:04:36Z
# c: 200 	 2012-11-11T23:09:02Z
# c: 300 	 2012-12-12T15:55:05Z
# query:cat:'cs.LG AND submittedDate:[20130101 TO 201303312359]'
# 20130101 arxiv read done.
# 20110401 arxiv read done. (128)
# c: 0 	 2011-04-01T15:26:43Z
# c: 100 	 2011-06-21T05:25:34Z
# query:cat:'cs.DC AND submittedDate:[20110701 TO 201109302359]'
# 20110701 arxiv read done. (110)
# c: 0 	 2011-07-01T14:16:33Z
# c: 100 	 2011-09-23T18:39:18Z
# query:cat:'cs.DC AND submittedDate:[20111001 TO 201112312359]'
# 20111001 arxiv read done. (116)
# c: 0 	 2011-10-03T12:09:05Z
# c: 100 	 2011-12-16T07:39:02Z
# query:cat:'cs.DC AND submittedDate:[20120101 TO 201203312359]'
# 20120101 arxiv read done. (127)
# c: 0 	 2012-01-01T12:58:24Z
# c: 100 	 2012-03-11T19:22:51Z
# query:cat:'cs.DC AND submittedDate:[20120401 TO 201206302359]'
# 20120401 arxiv read done. (139)
# c: 0 	 2012-04-02T07:48:02Z
# c: 100 	 2012-06-06T03:53:39Z
# query:cat:'cs.DC AND submittedDate:[20120701 TO 201209302359]'
# 20120701 arxiv read done. (143)
# c: 0 	 2012-07-01T13:10:15Z
# c: 100 	 2012-09-05T14:55:32Z
# query:cat:'cs.DC AND submittedDate:[20121001 TO 201212312359]'
# 20121001 arxiv read done. (140)
# c: 0 	 2012-10-01T10:25:50Z
# c: 100 	 2012-11-27T14:31:06Z
# query:cat:'cs.DC AND submittedDate:[20130101 TO 201303312359]'
# 20130101 arxiv read done. (148)
# c: 0 	 2013-01-01T01:54:28Z
# c: 100 	 2013-02-24T05:20:03Z
# query:cat:'cs.DC AND submittedDate:[20130401 TO 201306302359]'
# 20130401 arxiv read done. (156)
# c: 0 	 2013-04-01T00:14:45Z
# c: 100 	 2013-05-31T14:11:15Z
# query:cat:'cs.DC AND submittedDate:[20130701 TO 201309302359]'
# 20130701 arxiv read done. (162)
# c: 0 	 2013-07-01T16:41:40Z
# c: 100 	 2013-08-31T01:18:14Z
# query:cat:'cs.DC AND submittedDate:[20131001 TO 201312312359]'
# 20131001 arxiv read done. (216)
# c: 0 	 2013-10-01T15:33:30Z
# c: 100 	 2013-11-13T10:26:58Z
# c: 200 	 2013-12-21T00:56:56Z
# query:cat:'cs.DC AND submittedDate:[20140101 TO 201403312359]'
# 20140101 arxiv read done. (178)
# c: 0 	 2014-01-02T01:42:23Z
# c: 100 	 2014-02-22T16:29:22Z
# query:cat:'cs.DC AND submittedDate:[20140401 TO 201406302359]'
# 20140401 arxiv read done. (174)
# c: 0 	 2014-04-01T00:37:24Z
# c: 100 	 2014-05-12T16:51:53Z
# query:cat:'cs.DC AND submittedDate:[20140701 TO 201409302359]'
# 20140701 arxiv read done. (174)
# c: 0 	 2014-07-01T07:18:43Z
# c: 100 	 2014-08-13T15:26:35Z
# query:cat:'cs.DC AND submittedDate:[20141001 TO 201412312359]'
# 20141001 arxiv read done. (196)
# c: 0 	 2014-10-01T10:45:09Z
# c: 100 	 2014-11-14T07:14:05Z
# query:cat:'cs.DC AND submittedDate:[20150101 TO 201503312359]'
# 20150101 arxiv read done. (200)
# c: 0 	 2015-01-02T23:35:06Z
# c: 100 	 2015-02-13T11:01:29Z
# query:cat:'cs.DC AND submittedDate:[20150401 TO 201506302359]'
# 20150401 arxiv read done. (223)
# c: 0 	 2015-04-01T12:46:38Z
# c: 100 	 2015-05-18T13:43:46Z
# c: 200 	 2015-06-22T23:31:27Z
# query:cat:'cs.DC AND submittedDate:[20150701 TO 201509302359]'
# 20150701 arxiv read done. (248)
# c: 0 	 2015-07-01T00:12:35Z
# c: 100 	 2015-08-07T07:54:47Z
# c: 200 	 2015-09-09T11:38:01Z
# query:cat:'cs.DC AND submittedDate:[20151001 TO 201512312359]'
# 20151001 arxiv read done. (239)
# c: 0 	 2015-10-01T06:14:42Z
# c: 100 	 2015-11-06T17:36:20Z
# c: 200 	 2015-12-17T01:06:36Z
# query:cat:'cs.DC AND submittedDate:[20160101 TO 201603312359]'
# 20160101 arxiv read done. (246)
# c: 0 	 2016-01-01T11:18:31Z
# c: 100 	 2016-02-04T21:12:53Z
# c: 200 	 2016-03-13T19:28:20Z
# query:cat:'cs.DC AND submittedDate:[20160401 TO 201606302359]'
# 20160401 arxiv read done. (277)
# c: 0 	 2016-04-02T09:02:27Z
# c: 100 	 2016-05-04T17:57:18Z
# c: 200 	 2016-06-12T17:08:43Z
# query:cat:'cs.DC AND submittedDate:[20160701 TO 201609302359]'
# 20160701 arxiv read done. (251)
# c: 0 	 2016-07-01T09:35:28Z
# c: 100 	 2016-08-02T21:24:55Z
# c: 200 	 2016-09-13T11:49:36Z
# query:cat:'cs.DC AND submittedDate:[20161001 TO 201612312359]'
# 20161001 arxiv read done. (256)
# c: 0 	 2016-10-01T12:33:35Z
# c: 100 	 2016-11-04T11:07:53Z
# c: 200 	 2016-12-06T15:01:47Z
# query:cat:'cs.DC AND submittedDate:[20170101 TO 201703312359]'
# 20170101 arxiv read done. (296)
# c: 0 	 2017-01-01T00:10:42Z
# c: 100 	 2017-02-06T20:21:32Z
# c: 200 	 2017-03-03T15:14:07Z
# query:cat:'cs.DC AND submittedDate:[20170401 TO 201706302359]'
# 20170401 arxiv read done. (312)
# c: 0 	 2017-04-03T03:24:28Z
# c: 100 	 2017-05-01T19:30:58Z
# c: 200 	 2017-05-25T07:25:51Z
# c: 300 	 2017-06-26T13:34:50Z
# query:cat:'cs.DC AND submittedDate:[20170701 TO 201709302359]'
# 20170701 arxiv read done. (350)
# c: 0 	 2017-07-03T07:14:56Z
# c: 100 	 2017-08-03T19:22:23Z
# c: 200 	 2017-08-29T15:04:19Z
# c: 300 	 2017-09-20T11:15:01Z
# query:cat:'cs.DC AND submittedDate:[20171001 TO 201712312359]'
# 20171001 arxiv read done. (334)
# c: 0 	 2017-10-01T21:09:29Z
# c: 100 	 2017-10-26T21:34:34Z
# c: 200 	 2017-11-20T04:16:20Z
# c: 300 	 2017-12-20T14:28:21Z
# query:cat:'cs.DC AND submittedDate:[20180101 TO 201803312359]'
# 20180101 arxiv read done. (371)
# c: 0 	 2018-01-02T02:14:31Z
# c: 100 	 2018-01-31T17:17:30Z
# c: 200 	 2018-02-21T14:46:27Z
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/h2/connection.py in process_input(self, input_)
#     223         try:
# --> 224             func, target_state = self._transitions[(self.state, input_)]
#     225         except KeyError:
#
# KeyError: (<ConnectionState.CLOSED: 3>, <ConnectionInputs.RECV_PING: 14>)
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# <ipython-input-8-240b35857ea7> in <module>
#       1 get_10year_by_category(category="cs.LG")  #Learning
# ----> 2 get_10year_by_category(category="cs.DC")  #分散、並列、およびクラスターコンピューティング
#
# <ipython-input-4-7ea8de6b06c5> in get_10year_by_category(category)
#       3     os.makedirs(base_path, exist_ok=True)
#       4     for year in range(2010,2021):
# ----> 5         get_year_by_4q(year=str(year), category=category, base_path=base_path)
#       6
#       7     get_by_submitted_date("20210101", "202103312359")
#
# <ipython-input-3-abf13e07078f> in get_year_by_4q(year, category, base_path)
#      10
#      11     get_by_submitted_date(q1_start, q1_end, category=category, base_path=base_path)
# ---> 12     get_by_submitted_date(q2_start, q2_end, category=category, base_path=base_path)
#      13     get_by_submitted_date(q3_start, q3_end, category=category, base_path=base_path)
#      14     get_by_submitted_date(q4_start, q4_end, category=category, base_path=base_path)
#
# <ipython-input-2-2e2ec9cd5e7c> in get_by_submitted_date(start_date, end_date, category, base_path)
#      24             abst = abst.replace("\n","")
#      25
# ---> 26             title_jp =  str(translator.translate(title, src='en' ,dest='ja').text)
#      27             abst_jp =  str(translator.translate(abst, src='en' ,dest='ja').text)
#      28
#
# ~/.local/lib/python3.6/site-packages/googletrans/client.py in translate(self, text, dest, src)
#     192
#     193         origin = text
# --> 194         data, response = self._translate(text, dest, src)
#     195
#     196         token_found = False
#
# ~/.local/lib/python3.6/site-packages/googletrans/client.py in _translate(self, text, dest, src)
#     118             'rt': 'c',
#     119         }
# --> 120         r = self.client.post(url, params=params, data=data)
#     121
#     122         if r.status_code != 200 and self.raise_Exception:
#
# ~/.local/lib/python3.6/site-packages/httpx/_client.py in post(self, url, data, files, json, params, headers, cookies, auth, allow_redirects, timeout)
#     833             auth=auth,
#     834             allow_redirects=allow_redirects,
# --> 835             timeout=timeout,
#     836         )
#     837
#
# ~/.local/lib/python3.6/site-packages/httpx/_client.py in request(self, method, url, data, files, json, params, headers, cookies, auth, allow_redirects, timeout)
#     599         )
#     600         return self.send(
# --> 601             request, auth=auth, allow_redirects=allow_redirects, timeout=timeout,
#     602         )
#     603
#
# ~/.local/lib/python3.6/site-packages/httpx/_client.py in send(self, request, stream, auth, allow_redirects, timeout)
#     619
#     620         response = self.send_handling_redirects(
# --> 621             request, auth=auth, timeout=timeout, allow_redirects=allow_redirects,
#     622         )
#     623
#
# ~/.local/lib/python3.6/site-packages/httpx/_client.py in send_handling_redirects(self, request, auth, timeout, allow_redirects, history)
#     646
#     647             response = self.send_handling_auth(
# --> 648                 request, auth=auth, timeout=timeout, history=history
#     649             )
#     650             response.history = list(history)
#
# ~/.local/lib/python3.6/site-packages/httpx/_client.py in send_handling_auth(self, request, history, auth, timeout)
#     682         request = next(auth_flow)
#     683         while True:
# --> 684             response = self.send_single_request(request, timeout)
#     685             if auth.requires_response_body:
#     686                 response.read()
#
# ~/.local/lib/python3.6/site-packages/httpx/_client.py in send_single_request(self, request, timeout)
#     717                 headers=request.headers.raw,
#     718                 stream=request.stream,
# --> 719                 timeout=timeout.as_dict(),
#     720             )
#     721         except HTTPError as exc:
#
# ~/.local/lib/python3.6/site-packages/httpcore/_sync/connection_pool.py in request(self, method, url, headers, stream, timeout)
#     151             try:
#     152                 response = connection.request(
# --> 153                     method, url, headers=headers, stream=stream, timeout=timeout
#     154                 )
#     155             except NewConnectionRequired:
#
# ~/.local/lib/python3.6/site-packages/httpcore/_sync/connection.py in request(self, method, url, headers, stream, timeout)
#      76             "connection.request method=%r url=%r headers=%r", method, url, headers
#      77         )
# ---> 78         return self.connection.request(method, url, headers, stream, timeout)
#      79
#      80     def _open_socket(self, timeout: TimeoutDict = None) -> SyncSocketStream:
#
# ~/.local/lib/python3.6/site-packages/httpcore/_sync/http2.py in request(self, method, url, headers, stream, timeout)
#     116             self.streams[stream_id] = h2_stream
#     117             self.events[stream_id] = []
# --> 118             return h2_stream.request(method, url, headers, stream, timeout)
#     119         except Exception:
#     120             self.max_streams_semaphore.release()
#
# ~/.local/lib/python3.6/site-packages/httpcore/_sync/http2.py in request(self, method, url, headers, stream, timeout)
#     290
#     291         # Receive the response.
# --> 292         status_code, headers = self.receive_response(timeout)
#     293         reason_phrase = get_reason_phrase(status_code)
#     294         stream = SyncByteStream(
#
# ~/.local/lib/python3.6/site-packages/httpcore/_sync/http2.py in receive_response(self, timeout)
#     342         """
#     343         while True:
# --> 344             event = self.connection.wait_for_event(self.stream_id, timeout)
#     345             if isinstance(event, h2.events.ResponseReceived):
#     346                 break
#
# ~/.local/lib/python3.6/site-packages/httpcore/_sync/http2.py in wait_for_event(self, stream_id, timeout)
#     195         with self.read_lock:
#     196             while not self.events[stream_id]:
# --> 197                 self.receive_events(timeout)
#     198         return self.events[stream_id].pop(0)
#     199
#
# ~/.local/lib/python3.6/site-packages/httpcore/_sync/http2.py in receive_events(self, timeout)
#     203         """
#     204         data = self.socket.read(self.READ_NUM_BYTES, timeout)
# --> 205         events = self.h2_state.receive_data(data)
#     206         for event in events:
#     207             event_stream_id = getattr(event, "stream_id", 0)
#
# ~/.local/lib/python3.6/site-packages/h2/connection.py in receive_data(self, data)
#    1461         try:
#    1462             for frame in self.incoming_buffer:
# -> 1463                 events.extend(self._receive_frame(frame))
#    1464         except InvalidPaddingError:
#    1465             self._terminate_connection(ErrorCodes.PROTOCOL_ERROR)
#
# ~/.local/lib/python3.6/site-packages/h2/connection.py in _receive_frame(self, frame)
#    1484         try:
#    1485             # I don't love using __class__ here, maybe reconsider it.
# -> 1486             frames, events = self._frame_dispatch_table[frame.__class__](frame)
#    1487         except StreamClosedError as e:
#    1488             # If the stream was closed by RST_STREAM, we just send a RST_STREAM
#
# ~/.local/lib/python3.6/site-packages/h2/connection.py in _receive_ping_frame(self, frame)
#    1759         """
#    1760         events = self.state_machine.process_input(
# -> 1761             ConnectionInputs.RECV_PING
#    1762         )
#    1763         flags = []
#
# ~/.local/lib/python3.6/site-packages/h2/connection.py in process_input(self, input_)
#     227             self.state = ConnectionState.CLOSED
#     228             raise ProtocolError(
# --> 229                 "Invalid input %s in state %s" % (input_, old_state)
#     230             )
#     231         else:
#
# ProtocolError: Invalid input ConnectionInputs.RECV_PING in state ConnectionState.CLOSED

# %%
get_by_submitted_date("20190401", "201904302359", category="cs.LG")
get_by_submitted_date("20190501", "201905312359", category="cs.LG")
get_by_submitted_date("20190601", "201906302359", category="cs.LG")
get_by_submitted_date("20201001", "202010312359", category="cs.LG")
get_by_submitted_date("20201101", "202011302359", category="cs.LG")
get_by_submitted_date("20201201", "202012312359", category="cs.LG")

get_by_submitted_date("20190401", "201904302359", category="cs.AI")
get_by_submitted_date("20190501", "201905312359", category="cs.AI")
get_by_submitted_date("20190601", "201906302359", category="cs.AI")

get_by_submitted_date("20210101", "202103312359", category="eess.AS") #音声＆音声処理
get_by_submitted_date("20210101", "202103312359", category="cs.IR")   #情報検索
get_by_submitted_date("20210101", "202103312359", category="cs.IT")   #情報理論
get_by_submitted_date("20210101", "202103312359", category="cs.NE")   #ニューラルおよび進化的計算

get_by_submitted_date("20210101", "202103312359", category="cs.CL")   #Computation and Language
#      29             writer.writerow([r.published, r.updated, category, r.pdf_url, r.author, title, abst, title_jp, abst_jp, r.arxiv_comment, r.journal_reference ])
#
# ~/.local/lib/python3.6/site-packages/googletrans/client.py in translate(self, text, dest, src)
#     192
#     193         origin = text
# --> 194         data, response = self._translate(text, dest, src)
#     195
#     196         token_found = False
#
# ~/.local/lib/python3.6/site-packages/googletrans/client.py in _translate(self, text, dest, src)
#     118             'rt': 'c',
#     119         }
# --> 120         r = self.client.post(url, params=params, data=data)
#     121
#     122         if r.status_code != 200 and self.raise_Exception:
#
# ~/.local/lib/python3.6/site-packages/httpx/_client.py in post(self, url, data, files, json, params, headers, cookies, auth, allow_redirects, timeout)
#     833             auth=auth,
#     834             allow_redirects=allow_redirects,
# --> 835             timeout=timeout,
#     836         )
#     837
#
# ~/.local/lib/python3.6/site-packages/httpx/_client.py in request(self, method, url, data, files, json, params, headers, cookies, auth, allow_redirects, timeout)
#     599         )
#     600         return self.send(
# --> 601             request, auth=auth, allow_redirects=allow_redirects, timeout=timeout,
#     602         )
#     603
#
# ~/.local/lib/python3.6/site-packages/httpx/_client.py in send(self, request, stream, auth, allow_redirects, timeout)
#     619
#     620         response = self.send_handling_redirects(
# --> 621             request, auth=auth, timeout=timeout, allow_redirects=allow_redirects,
#     622         )
#     623
#
# ~/.local/lib/python3.6/site-packages/httpx/_client.py in send_handling_redirects(self, request, auth, timeout, allow_redirects, history)
#     646
#     647             response = self.send_handling_auth(
# --> 648                 request, auth=auth, timeout=timeout, history=history
#     649             )
#     650             response.history = list(history)
#
# ~/.local/lib/python3.6/site-packages/httpx/_client.py in send_handling_auth(self, request, history, auth, timeout)
#     682         request = next(auth_flow)
#     683         while True:
# --> 684             response = self.send_single_request(request, timeout)
#     685             if auth.requires_response_body:
#     686                 response.read()
#
# ~/.local/lib/python3.6/site-packages/httpx/_client.py in send_single_request(self, request, timeout)
#     717                 headers=request.headers.raw,
#     718                 stream=request.stream,
# --> 719                 timeout=timeout.as_dict(),
#     720             )
#     721         except HTTPError as exc:
#
# ~/.local/lib/python3.6/site-packages/httpcore/_sync/connection_pool.py in request(self, method, url, headers, stream, timeout)
#     151             try:
#     152                 response = connection.request(
# --> 153                     method, url, headers=headers, stream=stream, timeout=timeout
#     154                 )
#     155             except NewConnectionRequired:
#
# ~/.local/lib/python3.6/site-packages/httpcore/_sync/connection.py in request(self, method, url, headers, stream, timeout)
#      76             "connection.request method=%r url=%r headers=%r", method, url, headers
#      77         )
# ---> 78         return self.connection.request(method, url, headers, stream, timeout)
#      79
#      80     def _open_socket(self, timeout: TimeoutDict = None) -> SyncSocketStream:
#
# ~/.local/lib/python3.6/site-packages/httpcore/_sync/http2.py in request(self, method, url, headers, stream, timeout)
#     116             self.streams[stream_id] = h2_stream
#     117             self.events[stream_id] = []
# --> 118             return h2_stream.request(method, url, headers, stream, timeout)
#     119         except Exception:
#     120             self.max_streams_semaphore.release()
#
# ~/.local/lib/python3.6/site-packages/httpcore/_sync/http2.py in request(self, method, url, headers, stream, timeout)
#     290
#     291         # Receive the response.
# --> 292         status_code, headers = self.receive_response(timeout)
#     293         reason_phrase = get_reason_phrase(status_code)
#     294         stream = SyncByteStream(
#
# ~/.local/lib/python3.6/site-packages/httpcore/_sync/http2.py in receive_response(self, timeout)
#     342         """
#     343         while True:
# --> 344             event = self.connection.wait_for_event(self.stream_id, timeout)
#     345             if isinstance(event, h2.events.ResponseReceived):
#     346                 break
#
# ~/.local/lib/python3.6/site-packages/httpcore/_sync/http2.py in wait_for_event(self, stream_id, timeout)
#     195         with self.read_lock:
#     196             while not self.events[stream_id]:
# --> 197                 self.receive_events(timeout)
#     198         return self.events[stream_id].pop(0)
#     199
#
# ~/.local/lib/python3.6/site-packages/httpcore/_sync/http2.py in receive_events(self, timeout)
#     202         Read some data from the network, and update the H2 state.
#     203         """
# --> 204         data = self.socket.read(self.READ_NUM_BYTES, timeout)
#     205         events = self.h2_state.receive_data(data)
#     206         for event in events:
#
# ~/.local/lib/python3.6/site-packages/httpcore/_backends/sync.py in read(self, n, timeout)
#      60             with map_exceptions(exc_map):
#      61                 self.sock.settimeout(read_timeout)
# ---> 62                 return self.sock.recv(n)
#      63
#      64     def write(self, data: bytes, timeout: TimeoutDict) -> None:
#
# /usr/lib64/python3.6/contextlib.py in __exit__(self, type, value, traceback)
#      97                 value = type()
#      98             try:
# ---> 99                 self.gen.throw(type, value, traceback)
#     100             except StopIteration as exc:
#     101                 # Suppress StopIteration *unless* it's the same exception that
#
# ~/.local/lib/python3.6/site-packages/httpcore/_exceptions.py in map_exceptions(map)
#      10         for from_exc, to_exc in map.items():
#      11             if isinstance(exc, from_exc):
# ---> 12                 raise to_exc(exc) from None
#      13         raise
#      14
#
# ReadTimeout: The read operation timed out

# %%
get_by_submitted_date("20200801", "202008312359", category="cs.LG")
get_by_submitted_date("20200901", "202009302359", category="cs.LG")
# Out:
# query:cat:'cs.LG AND submittedDate:[20200801 TO 202008312359]'
# 20200801 arxiv read done. (1766)
# c: 0 	 2020-08-01T00:58:54Z
# c: 100 	 2020-08-03T15:28:40Z
# c: 200 	 2020-08-04T19:55:57Z
# c: 300 	 2020-08-06T07:36:55Z
# c: 400 	 2020-08-07T17:17:30Z
# c: 500 	 2020-08-09T20:00:57Z
# c: 600 	 2020-08-11T16:57:52Z
# c: 700 	 2020-08-13T02:24:28Z
# c: 800 	 2020-08-14T12:35:07Z
# c: 900 	 2020-08-17T04:46:25Z
# c: 1000 	 2020-08-18T11:05:40Z
# c: 1100 	 2020-08-19T17:51:30Z
# c: 1200 	 2020-08-21T07:26:55Z
# c: 1300 	 2020-08-23T14:55:37Z
# c: 1400 	 2020-08-25T07:33:52Z
# c: 1500 	 2020-08-26T16:34:58Z
# c: 1600 	 2020-08-28T02:03:18Z
# c: 1700 	 2020-08-30T14:39:28Z
# query:cat:'cs.LG AND submittedDate:[20200901 TO 202009302359]'
# 20200901 arxiv read done. (1831)
# c: 0 	 2020-09-01T00:06:50Z
# c: 100 	 2020-09-02T18:08:34Z
# c: 200 	 2020-09-04T13:53:46Z
# c: 300 	 2020-09-07T03:37:03Z
# c: 400 	 2020-09-08T16:49:12Z
# c: 500 	 2020-09-10T09:31:47Z
# c: 600 	 2020-09-11T17:53:20Z
# c: 700 	 2020-09-14T10:05:14Z
# c: 800 	 2020-09-15T15:22:42Z
# c: 900 	 2020-09-17T01:15:55Z
# c: 1000 	 2020-09-18T07:35:44Z
# c: 1100 	 2020-09-20T12:24:45Z
# c: 1200 	 2020-09-21T23:39:06Z
# c: 1300 	 2020-09-23T12:54:34Z
# c: 1400 	 2020-09-24T18:41:10Z
# c: 1500 	 2020-09-26T19:47:38Z
# c: 1600 	 2020-09-28T14:06:46Z
# c: 1700 	 2020-09-29T14:49:30Z
# c: 1800 	 2020-09-30T16:21:34Z

# %%
get_by_submitted_date("20210101", "202101312359", category="cs.LG")
get_by_submitted_date("20210201", "202102282359", category="cs.LG")
get_by_submitted_date("20210301", "202103312359", category="cs.LG")
get_by_submitted_date("20210401", "202104302359", category="cs.LG")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-32570a366441> in <module>
# ----> 1 get_by_submitted_date("20210101", "202101312359", category="cs.LG")
#       2 get_by_submitted_date("20210201", "202102282359", category="cs.LG")
#       3 get_by_submitted_date("20210301", "202103312359", category="cs.LG")
#       4 get_by_submitted_date("20210401", "202104302359", category="cs.LG")
#
# NameError: name 'get_by_submitted_date' is not defined
